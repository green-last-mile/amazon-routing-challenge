# %%
import sys
import pathlib
import os

def find_root(path):
    if os.path.split(path)[-1] != "amazon-routing-challenge":
        return find_root(os.path.split(path)[0])
    return path


ROOT = find_root(pathlib.Path().absolute())
sys.path.append(ROOT)

# %%
import json
import pandas as pd
import plotly.graph_objects as go
from dotenv import load_dotenv

_ = load_dotenv()

# %%
data_path = os.path.join(
    ROOT,
    "data",
    "almrrc2021-data-training",
    "model_build_inputs",
)

# %% [markdown]
# ## Open the Package Data

# %%
with open(os.path.join(data_path, "package_data.json"), 'r') as f:
    package_data = json.load(f)

# %%
# Out:
# {'AD': {'PackageID_9d7fdd03-f2cf-4c6f-9128-028258fc09ea': {'scan_status': 'DELIVERED',
#    'time_window': {'start_time_utc': nan, 'end_time_utc': nan},
#    'planned_service_time_seconds': 59.3,
#    'dimensions': {'depth_cm': 25.4, 'height_cm': 7.6, 'width_cm': 17.8}},
#   'PackageID_5541e679-b7bd-4992-b288-e862f6c84ae7': {'scan_status': 'DELIVERED',
#    'time_window': {'start_time_utc': '2018-07-27 16:00:00',
#     'end_time_utc': '2018-07-28 00:00:00'},
#    'planned_service_time_seconds': 59.3,
#    'dimensions': {'depth_cm': 25.4, 'height_cm': 12.7, 'width_cm': 17.8}},
#   'PackageID_84d0295b-1adb-4a33-a65e-f7d6247c7a07': {'scan_status': 'DELIVERED',
#    'time_window': {'start_time_utc': nan, 'end_time_utc': nan},
#    'planned_service_time_seconds': 59.3,
#    'dimensions': {'depth_cm': 39.4, 'height_cm': 7.6, 'width_cm': 31.8}}},
#  'AF': {'PackageID_15c6a204-ec5f-4ced-9c3d-472316cc7759': {'scan_status': 'DELIVERED',
#    'time_window': {'start_time_utc': '2018-07-27 16:00:00',
#     'end_time_utc': '2018-07-28 00:00:00'},
#    'planned_service_time_seconds': 27.0,
#    'dimensions': {'depth_cm': 30.0, 'height_cm': 3.0, 'width_cm': 27.4}}},
#  'AG': {'PackageID_3b28f781-242e-416e-9575-84c7188b8208': {'scan_status': 'DELIVERED',
#    'time_window': {'start_time_utc': nan, 'end_time_utc': nan},
#    'planned_service_time_seconds': 45.0,
#    'dimensions': {'depth_cm': 25.4, 'height_cm': 12.7, 'width_cm': 17.8}},
#   'PackageID_c58c3b4e-2fc7-4222-b712-e5067906736b': {'scan_status': 'DELIVERED',
#    'time_window': {'start_time_utc': nan, 'end_time_utc': nan},
#    'planned_service_time_seconds': 45.0,
#    'dimensions': {'depth_cm': 49.5, 'height_cm': 7.6, 'width_cm': 35.6}}},
#  'BA': {'PackageID_a18e36e0-6b5a-45b7-bf7a-7c3a15bd5a5d': {'scan_status': 'DELIVERED',
#    'time_window': {'start_time_utc': nan, 'end_time_utc': nan},
#    'planned_service_time_seconds': 38.0,
#    'dimensions': {'depth_cm': 24.4, 'height_cm': 1.0, 'width_cm': 16.8}}},
#  'BE': {'PackageID_22c8f630-8ab9-40d5-a36d-38ef01761b00': {'scan_status': 'DELIVERED',
#    'time_window': {'start_time_utc': nan, 'end_time_utc': nan},
#    'planned_service_time_seconds': 41.8,
#    'dimensions': {'depth_cm': 34.8, 'height_cm': 0.8, 'width_cm': 22.1}},
#   'PackageID_68c4cbf6-d23f-4675-a927-159ff3765efb': {'scan_status': 'DELIVERED',
#    'time_window': {'start_time_utc': nan, 'end_time_utc': nan},
#    'planned_service_time_seconds': 41.8,
#    'dimensions': {'depth_cm': 29.0, 'height_cm': 6.6, 'width_cm': 16.3}},
#   'PackageID_0d659fdd-4dbc-4f95-af88-5858048ca94f': {'scan_status': 'DELIVERED',
#    'time_window': {'start_time_utc': nan, 'end_time_utc': nan},
#    'planned_service_time_seconds': 41.8,
#    'dimensions': {'depth_cm': 45.7, 'height_cm': 21.6, 'width_cm': 22.9}},
#   'PackageID_3cd15fe7-5d24-4802-ac63-7c64f5cf6817': {'scan_status': 'DELIVERED',
#    'time_window': {'start_time_utc': nan, 'end_time_utc': nan},
#    'planned_service_time_seconds': 41.8,
#    'dimensions': {'depth_cm': 25.4, 'height_cm': 7.6, 'width_cm': 17.8}}},
#  'BG': {'PackageID_0934f8ee-81f4-4084-b54f-5fe3e6c64ba0': {'scan_status': 'DELIVERED',
#    'time_window': {'start_time_utc': '2018-07-27 16:00:00',
#     'end_time_utc': '2018-07-27 23:00:00'},
#    'planned_service_time_seconds': 54.7,
#    'dimensions': {'depth_cm': 31.8, 'height_cm': 1.3, 'width_cm': 29.2}},
#   'PackageID_98a78e9f-e75b-444d-9921-756258384f8e': {'scan_status': 'DELIVERED',
#    'time_window': {'start_time_utc': '2018-07-27 16:00:00',
#     'end_time_utc': '2018-07-27 23:00:00'},
#    'planned_service_time_seconds': 54.7,
#    'dimensions': {'depth_cm': 25.4, 'height_cm': 12.7, 'width_cm': 17.8}},
#   'PackageID_b86c4fbb-e30d-42e8-968f-f6d20174f5ca': {'scan_status': 'DELIVERED',
#    'time_window': {'start_time_utc': '2018-07-27 16:00:00',
#     'end_time_utc': '2018-07-27 23:00:00'},
#    'planned_service_time_seconds': 54.7,
#    'dimensions': {'depth_cm': 37.8, 'height_cm': 13.0, 'width_cm': 30.5}}},
#  'BP': {'PackageID_c734cbd5-768c-4c20-81df-f366c776274a': {'scan_status': 'DELIVERED',
#    'time_window': {'start_time_utc': '2018-07-27 17:30:00',
#     'end_time_utc': '2018-07-28 01:00:00'},
#    'planned_service_time_seconds': 42.0,
#    'dimensions': {'depth_cm': 25.4, 'height_cm': 7.6, 'width_cm': 17.8}},
#   'PackageID_d260086a-41c6-4805-81ec-cfa1803b30c1': {'scan_status': 'DELIVERED',
#    'time_window': {'start_time_utc': '2018-07-27 17:30:00',
#     'end_time_utc': '2018-07-28 01:00:00'},
#    'planned_service_time_seconds': 42.0,
#    'dimensions': {'depth_cm': 33.0, 'height_cm': 20.3, 'width_cm': 26.7}}},
#  'BT': {'PackageID_a595f722-d466-4981-a14e-3c5d30cbd225': {'scan_status': 'DELIVERED',
#    'time_window': {'start_time_utc': nan, 'end_time_utc': nan},
#    'planned_service_time_seconds': 59.7,
#    'dimensions': {'depth_cm': 30.7, 'height_cm': 2.3, 'width_cm': 28.2}},
#   'PackageID_0425564c-1ea6-4762-91da-4df3619f6c56': {'scan_status': 'DELIVERED',
#    'time_window': {'start_time_utc': nan, 'end_time_utc': nan},
#    'planned_service_time_seconds': 59.7,
#    'dimensions': {'depth_cm': 36.8, 'height_cm': 17.8, 'width_cm': 20.3}},
#   'PackageID_d2f677db-7969-4897-ba12-e34fa5e1a694': {'scan_status': 'DELIVERED',
#    'time_window': {'start_time_utc': nan, 'end_time_utc': nan},
#    'planned_service_time_seconds': 59.7,
#    'dimensions': {'depth_cm': 48.3, 'height_cm': 15.2, 'width_cm': 33.0}}},
#  'BY': {'PackageID_cb9b6e35-82f9-4d8e-a0a2-20c0407bf750': {'scan_status': 'DELIVERED',
#    'time_window': {'start_time_utc': nan, 'end_time_utc': nan},
#    'planned_service_time_seconds': 31.0,
#    'dimensions': {'depth_cm': 43.2, 'height_cm': 7.6, 'width_cm': 27.9}},
#   'PackageID_28f192d8-7a34-4551-bdf0-8ac512cb77a8': {'scan_status': 'DELIVERED',
#    'time_window': {'start_time_utc': nan, 'end_time_utc': nan},
#    'planned_service_time_seconds': 31.0,
#    'dimensions': {'depth_cm': 49.5, 'height_cm': 7.6, 'width_cm': 35.6}}},
#  'BZ': {'PackageID_6218c8a5-6ee8-4040-994f-a626b7565131': {'scan_status': 'DELIVERED',
#    'time_window': {'start_time_utc': nan, 'end_time_utc': nan},
#    'planned_service_time_seconds': 45.0,
#    'dimensions': {'depth_cm': 31.2, 'height_cm': 1.8, 'width_cm': 28.7}}},
#  'CA': {'PackageID_8a90dea1-cf2c-40f8-b91c-4998d32c4b9d': {'scan_status': 'DELIVERED',
#    'time_window': {'start_time_utc': '2018-07-27 16:00:00',
#     'end_time_utc': '2018-07-27 23:00:00'},
#    'planned_service_time_seconds': 47.5,
#    'dimensions': {'depth_cm': 25.4, 'height_cm': 12.7, 'width_cm': 17.8}},
#   'PackageID_d1d64da8-ade4-4936-9450-b28af876f75a': {'scan_status': 'DELIVERED',
#    'time_window': {'start_time_utc': '2018-07-27 16:00:00',
#     'end_time_utc': '2018-07-27 23:00:00'},
#    'planned_service_time_seconds': 47.5,
#    'dimensions': {'depth_cm': 33.0, 'height_cm': 20.3, 'width_cm': 26.7}}},
#  'CG': {'PackageID_6e7971b6-7beb-4998-800c-9b602be2e1ec': {'scan_status': 'DELIVERED',
#    'time_window': {'start_time_utc': '2018-07-27 16:00:00',
#     'end_time_utc': '2018-07-27 23:00:00'},
#    'planned_service_time_seconds': 24.5,
#    'dimensions': {'depth_cm': 34.3, 'height_cm': 7.6, 'width_cm': 24.1}},
#   'PackageID_14bd5219-973a-43b2-8e2c-3ffc39781d0a': {'scan_status': 'DELIVERED',
#    'time_window': {'start_time_utc': '2018-07-27 16:00:00',
#     'end_time_utc': '2018-07-27 23:00:00'},
#    'planned_service_time_seconds': 24.5,
#    'dimensions': {'depth_cm': 32.3, 'height_cm': 0.8, 'width_cm': 29.7}}},
#  'CK': {'PackageID_bd0157f6-b8a2-47b3-a1bc-cddb0e8c0877': {'scan_status': 'DELIVERED',
#    'time_window': {'start_time_utc': '2018-07-27 16:00:00',
#     'end_time_utc': '2018-07-27 23:00:00'},
#    'planned_service_time_seconds': 39.0,
#    'dimensions': {'depth_cm': 25.4, 'height_cm': 12.7, 'width_cm': 17.8}}},
#  'CM': {'PackageID_64f8d80c-9505-47f2-95de-1b0c513ede6e': {'scan_status': 'DELIVERED',
#    'time_window': {'start_time_utc': nan, 'end_time_utc': nan},
#    'planned_service_time_seconds': 22.0,
#    'dimensions': {'depth_cm': 22.6, 'height_cm': 5.3, 'width_cm': 16.8}}},
#  'CO': {'PackageID_48629125-eade-45b8-8892-09196ef42202': {'scan_status': 'DELIVERED',
#    'time_window': {'start_time_utc': nan, 'end_time_utc': nan},
#    'planned_service_time_seconds': 44.0,
#    'dimensions': {'depth_cm': 33.0, 'height_cm': 20.3, 'width_cm': 26.7}}},
#  'CP': {'PackageID_aa7529d1-c11b-4d7b-bcbb-de070c7be879': {'scan_status': 'DELIVERED',
#    'time_window': {'start_time_utc': nan, 'end_time_utc': nan},
#    'planned_service_time_seconds': 134.0,
#    'dimensions': {'depth_cm': 25.4, 'height_cm': 12.7, 'width_cm': 17.8}}},
#  'CW': {'PackageID_fba5c901-e813-45ca-85e2-90b5a98578f3': {'scan_status': 'DELIVERED',
#    'time_window': {'start_time_utc': nan, 'end_time_utc': nan},
#    'planned_service_time_seconds': 29.5,
#    'dimensions': {'depth_cm': 29.2, 'height_cm': 3.8, 'width_cm': 26.7}},
#   'PackageID_1bcc8776-e936-4ea2-a5fb-2e4aebf7ec39': {'scan_status': 'DELIVERED',
#    'time_window': {'start_time_utc': nan, 'end_time_utc': nan},
#    'planned_service_time_seconds': 29.5,
#    'dimensions': {'depth_cm': 30.5, 'height_cm': 4.3, 'width_cm': 22.9}}},
#  'DJ': {'PackageID_20238eb9-49a6-4c85-a3f4-04af7be773be': {'scan_status': 'DELIVERED',
#    'time_window': {'start_time_utc': nan, 'end_time_utc': nan},
#    'planned_service_time_seconds': 57.5,
#    'dimensions': {'depth_cm': 48.3, 'height_cm': 27.9, 'width_cm': 31.8}},
#   'PackageID_db16ffb3-39ee-4f94-b6c5-379eda118e1d': {'scan_status': 'DELIVERED',
#    'time_window': {'start_time_utc': nan, 'end_time_utc': nan},
#    'planned_service_time_seconds': 57.5,
#    'dimensions': {'depth_cm': 34.3, 'height_cm': 11.4, 'width_cm': 26.7}}},
#  'DL': {'PackageID_c9e63903-c4b0-4e44-9f12-ebb2b15b520f': {'scan_status': 'DELIVERED',
#    'time_window': {'start_time_utc': nan, 'end_time_utc': nan},
#    'planned_service_time_seconds': 130.0,
#    'dimensions': {'depth_cm': 53.3, 'height_cm': 15.2, 'width_cm': 38.1}}},
#  'DN': {'PackageID_3819fb8a-8b5b-4f33-af24-61bd6833cd47': {'scan_status': 'DELIVERED',
#    'time_window': {'start_time_utc': '2018-07-27 16:00:00',
#     'end_time_utc': '2018-07-27 20:00:00'},
#    'planned_service_time_seconds': 231.0,
#    'dimensions': {'depth_cm': 36.8, 'height_cm': 17.8, 'width_cm': 20.3}}},
#  'DQ': {'PackageID_7470aa09-ded8-4c01-8f9e-eb6ab3aae71d': {'scan_status': 'DELIVERED',
#    'time_window': {'start_time_utc': '2018-07-27 16:00:00',
#     'end_time_utc': '2018-07-27 23:00:00'},
#    'planned_service_time_seconds': 31.0,
#    'dimensions': {'depth_cm': 48.3, 'height_cm': 27.9, 'width_cm': 31.8}},
#   'PackageID_7debf7ad-d85e-4fe8-842d-a9762b8b0c4a': {'scan_status': 'DELIVERED',
#    'time_window': {'start_time_utc': '2018-07-27 16:00:00',
#     'end_time_utc': '2018-07-27 23:00:00'},
#    'planned_service_time_seconds': 31.0,
#    'dimensions': {'depth_cm': 20.3, 'height_cm': 5.1, 'width_cm': 12.7}}},
#  'EC': {'PackageID_13b60e9e-be2b-43e5-872b-c8247dc21555': {'scan_status': 'DELIVERED',
#    'time_window': {'start_time_utc': nan, 'end_time_utc': nan},
#    'planned_service_time_seconds': 24.5,
#    'dimensions': {'depth_cm': 31.6, 'height_cm': 1.4, 'width_cm': 29.1}},
#   'PackageID_5c77f325-0767-4a2b-a6dd-da6fb66ea2b1': {'scan_status': 'DELIVERED',
#    'time_window': {'start_time_utc': nan, 'end_time_utc': nan},
#    'planned_service_time_seconds': 24.5,
#    'dimensions': {'depth_cm': 30.3, 'height_cm': 5.3, 'width_cm': 17.6}},
#   'PackageID_20ee9948-8040-434b-8622-0afe6b63e84c': {'scan_status': 'DELIVERED',
#    'time_window': {'start_time_utc': nan, 'end_time_utc': nan},
#    'planned_service_time_seconds': 24.5,
#    'dimensions': {'depth_cm': 25.4, 'height_cm': 12.7, 'width_cm': 17.8}},
#   'PackageID_aa279827-1416-4635-a979-5ffd31bb5498': {'scan_status': 'DELIVERED',
#    'time_window': {'start_time_utc': nan, 'end_time_utc': nan},
#    'planned_service_time_seconds': 24.5,
#    'dimensions': {'depth_cm': 28.2, 'height_cm': 4.8, 'width_cm': 25.7}}},
#  'EH': {'PackageID_4d5dab14-2b9d-43b5-a4fc-df77eebce96c': {'scan_status': 'DELIVERED',
#    'time_window': {'start_time_utc': nan, 'end_time_utc': nan},
#    'planned_service_time_seconds': 75.0,
#    'dimensions': {'depth_cm': 30.5, 'height_cm': 4.3, 'width_cm': 19.8}}},
#  'EO': {'PackageID_fbd2132f-3e07-4d18-bddd-1681a521410c': {'scan_status': 'DELIVERED',
#    'time_window': {'start_time_utc': '2018-07-27 16:00:00',
#     'end_time_utc': '2018-07-27 23:00:00'},
#    'planned_service_time_seconds': 99.0,
#    'dimensions': {'depth_cm': 48.3, 'height_cm': 30.5, 'width_cm': 36.8}}},
#  'EX': {'PackageID_c755765e-beb4-42c2-ab0f-374f70166a96': {'scan_status': 'DELIVERED',
#    'time_window': {'start_time_utc': nan, 'end_time_utc': nan},
#    'planned_service_time_seconds': 18.5,
#    'dimensions': {'depth_cm': 33.0, 'height_cm': 8.9, 'width_cm': 30.5}},
#   'PackageID_2c24bae9-4e2c-4737-bc53-10d854fc303f': {'scan_status': 'DELIVERED',
#    'time_window': {'start_time_utc': nan, 'end_time_utc': nan},
#    'planned_service_time_seconds': 18.5,
#    'dimensions': {'depth_cm': 34.3, 'height_cm': 7.6, 'width_cm': 24.1}}},
#  'EY': {'PackageID_e6b65892-e08f-4ec7-aea9-6a6f388290f8': {'scan_status': 'DELIVERED',
#    'time_window': {'start_time_utc': nan, 'end_time_utc': nan},
#    'planned_service_time_seconds': 51.0,
#    'dimensions': {'depth_cm': 42.2, 'height_cm': 1.0, 'width_cm': 26.9}}},
#  'FF': {'PackageID_7283739f-b0b4-48ef-b9bf-e06ae69492f0': {'scan_status': 'DELIVERED',
#    'time_window': {'start_time_utc': nan, 'end_time_utc': nan},
#    'planned_service_time_seconds': 87.0,
#    'dimensions': {'depth_cm': 25.4, 'height_cm': 12.7, 'width_cm': 17.8}}},
#  'FH': {'PackageID_1bdc1614-e921-4ca6-883e-854435afa293': {'scan_status': 'DELIVERED',
#    'time_window': {'start_time_utc': nan, 'end_time_utc': nan},
#    'planned_service_time_seconds': 63.3,
#    'dimensions': {'depth_cm': 34.3, 'height_cm': 11.4, 'width_cm': 26.7}},
#   'PackageID_95c91492-09af-4dfe-a3f4-d7262a7c722c': {'scan_status': 'DELIVERED',
#    'time_window': {'start_time_utc': nan, 'end_time_utc': nan},
#    'planned_service_time_seconds': 63.3,
#    'dimensions': {'depth_cm': 53.3, 'height_cm': 15.2, 'width_cm': 38.1}},
#   'PackageID_e2e44ee0-5c56-44bf-a1e8-33add1cbf0e0': {'scan_status': 'DELIVERED',
#    'time_window': {'start_time_utc': nan, 'end_time_utc': nan},
#    'planned_service_time_seconds': 63.3,
#    'dimensions': {'depth_cm': 45.7, 'height_cm': 21.6, 'width_cm': 22.9}},
#   'PackageID_2dcad644-d4df-416b-b7ca-67958a1d9056': {'scan_status': 'DELIVERED',
#    'time_window': {'start_time_utc': nan, 'end_time_utc': nan},
#    'planned_service_time_seconds': 63.3,
#    'dimensions': {'depth_cm': 34.3, 'height_cm': 11.4, 'width_cm': 26.7}},
#   'PackageID_3377aa23-5eee-42e6-bd4c-82ced72ed4c5': {'scan_status': 'DELIVERED',
#    'time_window': {'start_time_utc': nan, 'end_time_utc': nan},
#    'planned_service_time_seconds': 63.3,
#    'dimensions': {'depth_cm': 36.8, 'height_cm': 17.8, 'width_cm': 20.3}},
#   'PackageID_c9e63903-c4b0-4e44-9f12-ebb2b15b520f': {'scan_status': 'DELIVERY_ATTEMPTED',
#    'time_window': {'start_time_utc': nan, 'end_time_utc': nan},
#    'planned_service_time_seconds': 63.3,
#    'dimensions': {'depth_cm': 53.3, 'height_cm': 15.2, 'width_cm': 38.1}}},
#  'FY': {'PackageID_d9fffa74-b346-4f6f-9102-8997c8e7d44c': {'scan_status': 'DELIVERED',
#    'time_window': {'start_time_utc': nan, 'end_time_utc': nan},
#    'planned_service_time_seconds': 33.3,
#    'dimensions': {'depth_cm': 34.3, 'height_cm': 7.6, 'width_cm': 24.1}},
#   'PackageID_b92bfbc9-c0b0-4afd-a350-ce055bb47f8c': {'scan_status': 'DELIVERED',
#    'time_window': {'start_time_utc': nan, 'end_time_utc': nan},
#    'planned_service_time_seconds': 33.3,
#    'dimensions': {'depth_cm': 40.4, 'height_cm': 2.8, 'width_cm': 25.1}},
#   'PackageID_f3dcca9f-b399-480a-8b76-2edb02db5ea7': {'scan_status': 'DELIVERED',
#    'time_window': {'start_time_utc': nan, 'end_time_utc': nan},
#    'planned_service_time_seconds': 33.3,
#    'dimensions': {'depth_cm': 44.5, 'height_cm': 20.3, 'width_cm': 35.6}}},
#  'GB': {'PackageID_4f6e31af-7458-4e0f-8afe-0a838b89e703': {'scan_status': 'DELIVERED',
#    'time_window': {'start_time_utc': nan, 'end_time_utc': nan},
#    'planned_service_time_seconds': 37.4,
#    'dimensions': {'depth_cm': 40.6, 'height_cm': 12.7, 'width_cm': 30.5}},
#   'PackageID_4c4c9716-32bf-4e7c-b6df-18e05ca61035': {'scan_status': 'DELIVERED',
#    'time_window': {'start_time_utc': nan, 'end_time_utc': nan},
#    'planned_service_time_seconds': 37.4,
#    'dimensions': {'depth_cm': 50.8, 'height_cm': 30.5, 'width_cm': 35.6}},
#   'PackageID_5329b45f-3096-41b5-aef2-3ac80a66935c': {'scan_status': 'DELIVERED',
#    'time_window': {'start_time_utc': nan, 'end_time_utc': nan},
#    'planned_service_time_seconds': 37.4,
#    'dimensions': {'depth_cm': 31.2, 'height_cm': 4.3, 'width_cm': 18.5}},
#   'PackageID_bb2993bd-ae86-4443-844d-a7e5eb7794ec': {'scan_status': 'DELIVERED',
#    'time_window': {'start_time_utc': nan, 'end_time_utc': nan},
#    'planned_service_time_seconds': 37.4,
#    'dimensions': {'depth_cm': 23.6, 'height_cm': 1.8, 'width_cm': 16.0}},
#   'PackageID_56ae9b56-f803-4552-b840-4b921284bedb': {'scan_status': 'DELIVERED',
#    'time_window': {'start_time_utc': nan, 'end_time_utc': nan},
#    'planned_service_time_seconds': 37.4,
#    'dimensions': {'depth_cm': 27.9, 'height_cm': 7.6, 'width_cm': 21.6}},
#   'PackageID_cee05fde-eeb2-44f9-a38d-d78efadd4438': {'scan_status': 'DELIVERED',
#    'time_window': {'start_time_utc': nan, 'end_time_utc': nan},
#    'planned_service_time_seconds': 37.4,
#    'dimensions': {'depth_cm': 49.5, 'height_cm': 7.6, 'width_cm': 35.6}},
#   'PackageID_013a4023-451e-431d-bec1-057e06ad401c': {'scan_status': 'DELIVERED',
#    'time_window': {'start_time_utc': nan, 'end_time_utc': nan},
#    'planned_service_time_seconds': 37.4,
#    'dimensions': {'depth_cm': 25.3, 'height_cm': 7.7, 'width_cm': 22.8}}},
#  'GN': {'PackageID_a2c556f2-629f-4b5a-9779-e13aabe3a545': {'scan_status': 'DELIVERED',
#    'time_window': {'start_time_utc': nan, 'end_time_utc': nan},
#    'planned_service_time_seconds': 54.0,
#    'dimensions': {'depth_cm': 30.3, 'height_cm': 2.7, 'width_cm': 27.8}}},
#  'GP': {'PackageID_99fdaa4b-9b64-4b6d-beb0-5a76a7c2e031': {'scan_status': 'DELIVERED',
#    'time_window': {'start_time_utc': nan, 'end_time_utc': nan},
#    'planned_service_time_seconds': 34.0,
#    'dimensions': {'depth_cm': 30.5, 'height_cm': 10.2, 'width_cm': 19.1}}},
#  'GS': {'PackageID_f52aa2c7-dc2f-48c2-be37-0eb957d2b075': {'scan_status': 'DELIVERED',
#    'time_window': {'start_time_utc': nan, 'end_time_utc': nan},
#    'planned_service_time_seconds': 40.5,
#    'dimensions': {'depth_cm': 30.5, 'height_cm': 2.5, 'width_cm': 27.9}},
#   'PackageID_53a745b9-29a5-48f8-a0bc-b71a54ceb157': {'scan_status': 'DELIVERED',
#    'time_window': {'start_time_utc': nan, 'end_time_utc': nan},
#    'planned_service_time_seconds': 40.5,
#    'dimensions': {'depth_cm': 34.3, 'height_cm': 11.4, 'width_cm': 26.7}}},
#  'GU': {'PackageID_2bc50fa7-7bd8-4918-8b2e-83cd657e6fff': {'scan_status': 'DELIVERED',
#    'time_window': {'start_time_utc': '2018-07-27 16:00:00',
#     'end_time_utc': '2018-07-28 00:00:00'},
#    'planned_service_time_seconds': 69.0,
#    'dimensions': {'depth_cm': 34.3, 'height_cm': 7.6, 'width_cm': 24.1}},
#   'PackageID_70b06162-081f-401b-af33-940b44612add': {'scan_status': 'DELIVERED',
#    'time_window': {'start_time_utc': nan, 'end_time_utc': nan},
#    'planned_service_time_seconds': 69.0,
#    'dimensions': {'depth_cm': 25.4, 'height_cm': 12.7, 'width_cm': 17.8}},
#   'PackageID_f2a10032-5a27-419e-ba1c-75ced7d8fd6f': {'scan_status': 'DELIVERED',
#    'time_window': {'start_time_utc': nan, 'end_time_utc': nan},
#    'planned_service_time_seconds': 69.0,
#    'dimensions': {'depth_cm': 53.3, 'height_cm': 15.2, 'width_cm': 38.1}}},
#  'GW': {'PackageID_bd1c2ea9-fcc2-40f8-abb6-05b25e01c765': {'scan_status': 'DELIVERED',
#    'time_window': {'start_time_utc': nan, 'end_time_utc': nan},
#    'planned_service_time_seconds': 64.0,
#    'dimensions': {'depth_cm': 24.1, 'height_cm': 1.3, 'width_cm': 16.5}},
#   'PackageID_5e6bd154-6b55-48af-82d2-9f4d531cfe3a': {'scan_status': 'DELIVERED',
#    'time_window': {'start_time_utc': nan, 'end_time_utc': nan},
#    'planned_service_time_seconds': 64.0,
#    'dimensions': {'depth_cm': 35.6, 'height_cm': 22.9, 'width_cm': 31.8}}},
#  'HB': {'PackageID_39c23514-56c1-4d15-a449-85fff43b84e9': {'scan_status': 'DELIVERED',
#    'time_window': {'start_time_utc': nan, 'end_time_utc': nan},
#    'planned_service_time_seconds': 43.0,
#    'dimensions': {'depth_cm': 50.8, 'height_cm': 30.5, 'width_cm': 35.6}},
#   'PackageID_459ce5a6-b339-4dbd-a179-dd54f832f1a9': {'scan_status': 'DELIVERED',
#    'time_window': {'start_time_utc': nan, 'end_time_utc': nan},
#    'planned_service_time_seconds': 43.0,
#    'dimensions': {'depth_cm': 43.2, 'height_cm': 27.9, 'width_cm': 30.5}},
#   'PackageID_5e352fd6-c736-4e81-bb3b-d46548a87188': {'scan_status': 'DELIVERED',
#    'time_window': {'start_time_utc': nan, 'end_time_utc': nan},
#    'planned_service_time_seconds': 43.0,
#    'dimensions': {'depth_cm': 49.3, 'height_cm': 34.5, 'width_cm': 42.2}},
#   'PackageID_83d28025-ca3f-48dd-ad0e-3902f197e93f': {'scan_status': 'DELIVERED',
#    'time_window': {'start_time_utc': nan, 'end_time_utc': nan},
#    'planned_service_time_seconds': 43.0,
#    'dimensions': {'depth_cm': 40.6, 'height_cm': 12.7, 'width_cm': 30.5}}},
#  'HG': {'PackageID_96d4e109-0368-48e1-8660-f3b12337dca5': {'scan_status': 'DELIVERED',
#    'time_window': {'start_time_utc': nan, 'end_time_utc': nan},
#    'planned_service_time_seconds': 55.0,
#    'dimensions': {'depth_cm': 34.3, 'height_cm': 11.4, 'width_cm': 26.7}}},
#  'HN': {'PackageID_514945f9-cdb5-4719-80fa-b01066607530': {'scan_status': 'DELIVERED',
#    'time_window': {'start_time_utc': '2018-07-27 16:00:00',
#     'end_time_utc': '2018-07-28 00:00:00'},
#    'planned_service_time_seconds': 52.5,
#    'dimensions': {'depth_cm': 22.9, 'height_cm': 2.5, 'width_cm': 15.2}},
#   'PackageID_3dfd07aa-fe4c-4c29-8e3c-cbe64b906447': {'scan_status': 'DELIVERED',
#    'time_window': {'start_time_utc': '2018-07-27 16:00:00',
#     'end_time_utc': '2018-07-27 23:00:00'},
#    'planned_service_time_seconds': 52.5,
#    'dimensions': {'depth_cm': 43.2, 'height_cm': 7.6, 'width_cm': 27.9}}},
#  'HO': {'PackageID_e0b82443-fa71-4a19-8710-31f02bd0f652': {'scan_status': 'DELIVERED',
#    'time_window': {'start_time_utc': nan, 'end_time_utc': nan},
#    'planned_service_time_seconds': 31.5,
#    'dimensions': {'depth_cm': 24.1, 'height_cm': 1.8, 'width_cm': 16.5}},
#   'PackageID_e5164bc3-9cf1-4257-ac12-c081a31d3141': {'scan_status': 'DELIVERED',
#    'time_window': {'start_time_utc': nan, 'end_time_utc': nan},
#    'planned_service_time_seconds': 31.5,
#    'dimensions': {'depth_cm': 43.2, 'height_cm': 7.6, 'width_cm': 27.9}}},
#  'HR': {'PackageID_899d538b-9b98-400f-a019-a3861a6bd45e': {'scan_status': 'DELIVERED',
#    'time_window': {'start_time_utc': nan, 'end_time_utc': nan},
#    'planned_service_time_seconds': 17.0,
#    'dimensions': {'depth_cm': 38.9, 'height_cm': 21.3, 'width_cm': 24.1}}},
#  'HT': {'PackageID_581892a8-0e1c-46b1-b92f-b7285564a41a': {'scan_status': 'DELIVERED',
#    'time_window': {'start_time_utc': nan, 'end_time_utc': nan},
#    'planned_service_time_seconds': 72.5,
#    'dimensions': {'depth_cm': 34.3, 'height_cm': 7.6, 'width_cm': 24.1}},
#   'PackageID_37371bb1-4082-40d7-9e97-4ec639d47035': {'scan_status': 'DELIVERED',
#    'time_window': {'start_time_utc': nan, 'end_time_utc': nan},
#    'planned_service_time_seconds': 72.5,
#    'dimensions': {'depth_cm': 25.1, 'height_cm': 5.1, 'width_cm': 13.5}}},
#  'HW': {'PackageID_8f4ec61b-706e-40d9-a25d-d0b90dd4b257': {'scan_status': 'DELIVERED',
#    'time_window': {'start_time_utc': nan, 'end_time_utc': nan},
#    'planned_service_time_seconds': 65.7,
#    'dimensions': {'depth_cm': 49.5, 'height_cm': 7.6, 'width_cm': 35.6}},
#   'PackageID_974a2f89-3aae-4b34-ab30-b5b81ec67716': {'scan_status': 'DELIVERED',
#    'time_window': {'start_time_utc': nan, 'end_time_utc': nan},
#    'planned_service_time_seconds': 65.7,
#    'dimensions': {'depth_cm': 39.4, 'height_cm': 7.6, 'width_cm': 31.8}},
#   'PackageID_2aa3854a-5d01-4534-894c-b1e4be9fa411': {'scan_status': 'DELIVERED',
#    'time_window': {'start_time_utc': nan, 'end_time_utc': nan},
#    'planned_service_time_seconds': 65.7,
#    'dimensions': {'depth_cm': 49.5, 'height_cm': 7.6, 'width_cm': 35.6}}},
#  'IA': {'PackageID_d5ecbbea-3476-4e07-afd3-aa3315201995': {'scan_status': 'DELIVERED',
#    'time_window': {'start_time_utc': '2018-07-27 16:00:00',
#     'end_time_utc': '2018-07-27 23:00:00'},
#    'planned_service_time_seconds': 64.0,
#    'dimensions': {'depth_cm': 34.3, 'height_cm': 11.4, 'width_cm': 20.3}}},
#  'IJ': {'PackageID_8d572881-2887-48f8-b04c-e52118996dac': {'scan_status': 'DELIVERED',
#    'time_window': {'start_time_utc': nan, 'end_time_utc': nan},
#    'planned_service_time_seconds': 40.0,
#    'dimensions': {'depth_cm': 29.4, 'height_cm': 6.2, 'width_cm': 16.7}}},
#  'IM': {'PackageID_2acb348a-d5a1-41b6-b727-5f00eb85b891': {'scan_status': 'DELIVERED',
#    'time_window': {'start_time_utc': nan, 'end_time_utc': nan},
#    'planned_service_time_seconds': 28.0,
#    'dimensions': {'depth_cm': 25.4, 'height_cm': 12.7, 'width_cm': 17.8}}},
#  'IP': {'PackageID_6def27bc-7c41-4186-b49e-cce1102ef786': {'scan_status': 'DELIVERED',
#    'time_window': {'start_time_utc': '2018-07-27 16:00:00',
#     'end_time_utc': '2018-07-28 00:00:00'},
#    'planned_service_time_seconds': 35.0,
#    'dimensions': {'depth_cm': 29.2, 'height_cm': 6.3, 'width_cm': 16.5}}},
#  'IW': {'PackageID_85f7a267-f4ac-4d62-8ade-4e0d8f40b56c': {'scan_status': 'DELIVERED',
#    'time_window': {'start_time_utc': nan, 'end_time_utc': nan},
#    'planned_service_time_seconds': 33.7,
#    'dimensions': {'depth_cm': 25.1, 'height_cm': 0.3, 'width_cm': 17.5}},
#   'PackageID_2aac3acb-fc0c-48b6-9f9a-6573b304e3a6': {'scan_status': 'DELIVERED',
#    'time_window': {'start_time_utc': nan, 'end_time_utc': nan},
#    'planned_service_time_seconds': 33.7,
#    'dimensions': {'depth_cm': 36.8, 'height_cm': 17.8, 'width_cm': 20.3}},
#   'PackageID_2b7cde55-4b87-4fcb-b69a-e0877a940533': {'scan_status': 'DELIVERED',
#    'time_window': {'start_time_utc': nan, 'end_time_utc': nan},
#    'planned_service_time_seconds': 33.7,
#    'dimensions': {'depth_cm': 23.6, 'height_cm': 1.8, 'width_cm': 16.0}}},
#  'JH': {'PackageID_c7431b36-acab-43e5-a697-866d1f342a67': {'scan_status': 'DELIVERED',
#    'time_window': {'start_time_utc': nan, 'end_time_utc': nan},
#    'planned_service_time_seconds': 37.0,
#    'dimensions': {'depth_cm': 31.8, 'height_cm': 11.4, 'width_cm': 16.5}}},
#  'JM': {'PackageID_2626e99d-00b8-4516-9230-52194776362d': {'scan_status': 'DELIVERED',
#    'time_window': {'start_time_utc': nan, 'end_time_utc': nan},
#    'planned_service_time_seconds': 31.0,
#    'dimensions': {'depth_cm': 30.7, 'height_cm': 2.3, 'width_cm': 28.2}}},
#  'KA': {'PackageID_caa811ef-5072-423b-a818-5a3e23768fed': {'scan_status': 'DELIVERED',
#    'time_window': {'start_time_utc': nan, 'end_time_utc': nan},
#    'planned_service_time_seconds': 40.5,
#    'dimensions': {'depth_cm': 28.7, 'height_cm': 4.3, 'width_cm': 26.2}},
#   'PackageID_7767f623-b25f-4876-b309-329435c462e7': {'scan_status': 'DELIVERED',
#    'time_window': {'start_time_utc': nan, 'end_time_utc': nan},
#    'planned_service_time_seconds': 40.5,
#    'dimensions': {'depth_cm': 29.5, 'height_cm': 6.1, 'width_cm': 16.8}},
#   'PackageID_a797e52d-fd77-402f-a314-fb82cbdacba6': {'scan_status': 'DELIVERED',
#    'time_window': {'start_time_utc': nan, 'end_time_utc': nan},
#    'planned_service_time_seconds': 40.5,
#    'dimensions': {'depth_cm': 28.4, 'height_cm': 4.6, 'width_cm': 25.9}},
#   'PackageID_2ed3dafd-bd98-4a3d-a861-ef7a9da41875': {'scan_status': 'DELIVERED',
#    'time_window': {'start_time_utc': nan, 'end_time_utc': nan},
#    'planned_service_time_seconds': 40.5,
#    'dimensions': {'depth_cm': 34.3, 'height_cm': 11.4, 'width_cm': 26.7}}},
#  'KG': {'PackageID_fcc16600-1735-47e0-b8c1-dfa504634d20': {'scan_status': 'DELIVERED',
#    'time_window': {'start_time_utc': '2018-07-27 16:00:00',
#     'end_time_utc': '2018-07-27 23:00:00'},
#    'planned_service_time_seconds': 89.0,
#    'dimensions': {'depth_cm': 35.6, 'height_cm': 22.9, 'width_cm': 31.8}}},
#  'KJ': {'PackageID_5ca89540-d2fa-4253-bb81-dc895850e6ce': {'scan_status': 'DELIVERED',
#    'time_window': {'start_time_utc': nan, 'end_time_utc': nan},
#    'planned_service_time_seconds': 22.0,
#    'dimensions': {'depth_cm': 27.9, 'height_cm': 5.1, 'width_cm': 25.4}},
#   'PackageID_484b76ed-ed86-47f3-b263-3005e1ca3997': {'scan_status': 'DELIVERED',
#    'time_window': {'start_time_utc': nan, 'end_time_utc': nan},
#    'planned_service_time_seconds': 22.0,
#    'dimensions': {'depth_cm': 35.6, 'height_cm': 7.6, 'width_cm': 20.3}},
#   'PackageID_70e66814-f1b3-490e-8c3f-4d5124745548': {'scan_status': 'DELIVERED',
#    'time_window': {'start_time_utc': nan, 'end_time_utc': nan},
#    'planned_service_time_seconds': 22.0,
#    'dimensions': {'depth_cm': 25.1, 'height_cm': 0.3, 'width_cm': 17.5}}},
#  'KM': {'PackageID_e7ed0d4f-ceb7-4588-816c-446a936fea63': {'scan_status': 'DELIVERED',
#    'time_window': {'start_time_utc': nan, 'end_time_utc': nan},
#    'planned_service_time_seconds': 40.3,
#    'dimensions': {'depth_cm': 23.5, 'height_cm': 1.9, 'width_cm': 15.9}},
#   'PackageID_17b804aa-b7c6-4dad-aff8-41ae8a0c5a26': {'scan_status': 'DELIVERED',
#    'time_window': {'start_time_utc': nan, 'end_time_utc': nan},
#    'planned_service_time_seconds': 40.3,
#    'dimensions': {'depth_cm': 30.0, 'height_cm': 5.6, 'width_cm': 17.3}},
#   'PackageID_b7fe1d29-c3ef-4fc1-8fb0-5d81e465bd29': {'scan_status': 'DELIVERED',
#    'time_window': {'start_time_utc': nan, 'end_time_utc': nan},
#    'planned_service_time_seconds': 40.3,
#    'dimensions': {'depth_cm': 24.1, 'height_cm': 2.3, 'width_cm': 16.5}}},
#  'KN': {'PackageID_101e0488-6bfb-4067-a3d0-52f3d1f13d55': {'scan_status': 'DELIVERED',
#    'time_window': {'start_time_utc': nan, 'end_time_utc': nan},
#    'planned_service_time_seconds': 46.0,
#    'dimensions': {'depth_cm': 31.8, 'height_cm': 1.3, 'width_cm': 29.2}},
#   'PackageID_41c5a224-633b-40cd-bfe8-ea21c1fb6790': {'scan_status': 'DELIVERED',
#    'time_window': {'start_time_utc': nan, 'end_time_utc': nan},
#    'planned_service_time_seconds': 46.0,
#    'dimensions': {'depth_cm': 25.4, 'height_cm': 7.6, 'width_cm': 17.8}},
#   'PackageID_b6b0fe36-66fa-4f65-9909-6d260d74f798': {'scan_status': 'DELIVERED',
#    'time_window': {'start_time_utc': nan, 'end_time_utc': nan},
#    'planned_service_time_seconds': 46.0,
#    'dimensions': {'depth_cm': 36.8, 'height_cm': 17.8, 'width_cm': 20.3}},
#   'PackageID_0b815ae0-ffbd-4658-94eb-b6a7f8b5faed': {'scan_status': 'DELIVERED',
#    'time_window': {'start_time_utc': nan, 'end_time_utc': nan},
#    'planned_service_time_seconds': 46.0,
#    'dimensions': {'depth_cm': 25.4, 'height_cm': 7.6, 'width_cm': 17.8}}},
#  'KP': {'PackageID_beb78639-3b7a-4c5b-b8e4-d5897ab4fc4f': {'scan_status': 'DELIVERED',
#    'time_window': {'start_time_utc': nan, 'end_time_utc': nan},
#    'planned_service_time_seconds': 58.6,
#    'dimensions': {'depth_cm': 33.0, 'height_cm': 20.3, 'width_cm': 26.7}},
#   'PackageID_03c21f21-61f6-470b-a564-ec38d394b3a5': {'scan_status': 'DELIVERED',
#    'time_window': {'start_time_utc': nan, 'end_time_utc': nan},
#    'planned_service_time_seconds': 58.6,
#    'dimensions': {'depth_cm': 25.4, 'height_cm': 7.6, 'width_cm': 17.8}},
#   'PackageID_5b256aa2-4e08-4841-b56c-6752a92498e2': {'scan_status': 'DELIVERED',
#    'time_window': {'start_time_utc': nan, 'end_time_utc': nan},
#    'planned_service_time_seconds': 58.6,
#    'dimensions': {'depth_cm': 43.2, 'height_cm': 7.6, 'width_cm': 27.9}},
#   'PackageID_1b91ddbd-b47c-4612-87e7-d778cd6edf2c': {'scan_status': 'DELIVERED',
#    'time_window': {'start_time_utc': nan, 'end_time_utc': nan},
#    'planned_service_time_seconds': 58.6,
#    'dimensions': {'depth_cm': 31.0, 'height_cm': 2.0, 'width_cm': 28.5}},
#   'PackageID_9885dfac-9afe-46fe-a159-137f0a559e46': {'scan_status': 'DELIVERED',
#    'time_window': {'start_time_utc': nan, 'end_time_utc': nan},
#    'planned_service_time_seconds': 58.6,
#    'dimensions': {'depth_cm': 34.3, 'height_cm': 11.4, 'width_cm': 26.7}}},
#  'KU': {'PackageID_b6bc96a4-acf9-4aa1-8c1a-acbfdc26b17d': {'scan_status': 'DELIVERED',
#    'time_window': {'start_time_utc': nan, 'end_time_utc': nan},
#    'planned_service_time_seconds': 52.0,
#    'dimensions': {'depth_cm': 36.8, 'height_cm': 17.8, 'width_cm': 20.3}}},
#  'LB': {'PackageID_80b8f496-ab73-4aa0-8871-57dd5a2672a6': {'scan_status': 'DELIVERED',
#    'time_window': {'start_time_utc': nan, 'end_time_utc': nan},
#    'planned_service_time_seconds': 63.0,
#    'dimensions': {'depth_cm': 33.0, 'height_cm': 20.3, 'width_cm': 26.7}}},
#  'LD': {'PackageID_d50dd33d-e75e-41b7-9e4d-6be54d91aa91': {'scan_status': 'DELIVERED',
#    'time_window': {'start_time_utc': '2018-07-27 16:00:00',
#     'end_time_utc': '2018-07-28 01:00:00'},
#    'planned_service_time_seconds': 163.0,
#    'dimensions': {'depth_cm': 39.4, 'height_cm': 7.6, 'width_cm': 31.8}}},
#  'LG': {'PackageID_325426e6-50e5-49c4-afbb-656eb7fc8cb0': {'scan_status': 'DELIVERED',
#    'time_window': {'start_time_utc': '2018-07-27 16:00:00',
#     'end_time_utc': '2018-07-27 23:00:00'},
#    'planned_service_time_seconds': 79.0,
#    'dimensions': {'depth_cm': 35.6, 'height_cm': 6.6, 'width_cm': 22.9}}},
#  'LK': {'PackageID_9d467dfa-4d0d-4a20-9050-87c1468d83ac': {'scan_status': 'DELIVERED',
#    'time_window': {'start_time_utc': nan, 'end_time_utc': nan},
#    'planned_service_time_seconds': 34.0,
#    'dimensions': {'depth_cm': 27.9, 'height_cm': 7.6, 'width_cm': 21.6}}},
#  'LY': {'PackageID_f38c8c06-160a-44d2-af4e-cb16bf3fe1ed': {'scan_status': 'DELIVERED',
#    'time_window': {'start_time_utc': nan, 'end_time_utc': nan},
#    'planned_service_time_seconds': 34.5,
#    'dimensions': {'depth_cm': 31.8, 'height_cm': 11.4, 'width_cm': 16.5}},
#   'PackageID_4af0103a-6b71-4c8a-a280-3c72ddf873ae': {'scan_status': 'DELIVERED',
#    'time_window': {'start_time_utc': nan, 'end_time_utc': nan},
#    'planned_service_time_seconds': 34.5,
#    'dimensions': {'depth_cm': 27.8, 'height_cm': 5.2, 'width_cm': 25.3}}},
#  'MA': {'PackageID_c2857c37-7951-4913-89d4-a6c0ef1510b5': {'scan_status': 'DELIVERED',
#    'time_window': {'start_time_utc': '2018-07-27 16:00:00',
#     'end_time_utc': '2018-07-27 20:00:00'},
#    'planned_service_time_seconds': 47.6,
#    'dimensions': {'depth_cm': 35.6, 'height_cm': 22.9, 'width_cm': 31.8}},
#   'PackageID_60668c4b-dc63-4aa2-8eee-5b71af4a6509': {'scan_status': 'DELIVERED',
#    'time_window': {'start_time_utc': '2018-07-27 16:00:00',
#     'end_time_utc': '2018-07-27 20:00:00'},
#    'planned_service_time_seconds': 47.6,
#    'dimensions': {'depth_cm': 33.0, 'height_cm': 20.3, 'width_cm': 26.7}},
#   'PackageID_10c67725-2b27-4679-8866-ab3441d987cb': {'scan_status': 'DELIVERED',
#    'time_window': {'start_time_utc': '2018-07-27 16:00:00',
#     'end_time_utc': '2018-07-27 20:00:00'},
#    'planned_service_time_seconds': 47.6,
#    'dimensions': {'depth_cm': 25.4, 'height_cm': 12.7, 'width_cm': 17.8}},
#   'PackageID_120c8dfe-ddc0-4e28-980d-19027703cf7c': {'scan_status': 'DELIVERED',
#    'time_window': {'start_time_utc': '2018-07-27 16:00:00',
#     'end_time_utc': '2018-07-27 20:00:00'},
#    'planned_service_time_seconds': 47.6,
#    'dimensions': {'depth_cm': 34.3, 'height_cm': 11.4, 'width_cm': 26.7}},
#   'PackageID_b4855392-f3ef-43c1-97c9-ec4890979e4f': {'scan_status': 'DELIVERED',
#    'time_window': {'start_time_utc': '2018-07-27 16:00:00',
#     'end_time_utc': '2018-07-27 20:00:00'},
#    'planned_service_time_seconds': 47.6,
#    'dimensions': {'depth_cm': 48.3, 'height_cm': 15.2, 'width_cm': 33.0}},
#   'PackageID_c4093f98-2e82-47e8-ac25-b4c1101a4bae': {'scan_status': 'DELIVERED',
#    'time_window': {'start_time_utc': '2018-07-27 16:00:00',
#     'end_time_utc': '2018-07-27 20:00:00'},
#    'planned_service_time_seconds': 47.6,
#    'dimensions': {'depth_cm': 34.3, 'height_cm': 7.6, 'width_cm': 24.1}},
#   'PackageID_8c86df7b-86fb-4947-895e-dd4d8274a92a': {'scan_status': 'DELIVERED',
#    'time_window': {'start_time_utc': '2018-07-27 16:00:00',
#     'end_time_utc': '2018-07-28 00:00:00'},
#    'planned_service_time_seconds': 47.6,
#    'dimensions': {'depth_cm': 36.8, 'height_cm': 17.8, 'width_cm': 20.3}},
#   'PackageID_b9ad4184-bd96-4d66-9fff-d01214b2a3af': {'scan_status': 'DELIVERED',
#    'time_window': {'start_time_utc': '2018-07-27 16:00:00',
#     'end_time_utc': '2018-07-28 00:00:00'},
#    'planned_service_time_seconds': 47.6,
#    'dimensions': {'depth_cm': 40.6, 'height_cm': 12.7, 'width_cm': 30.5}},
#   'PackageID_8d715fca-dd6a-4fd1-a466-3913fea41cc8': {'scan_status': 'DELIVERED',
#    'time_window': {'start_time_utc': '2018-07-27 16:00:00',
#     'end_time_utc': '2018-07-28 00:00:00'},
#    'planned_service_time_seconds': 47.6,
#    'dimensions': {'depth_cm': 36.8, 'height_cm': 17.8, 'width_cm': 20.3}},
#   'PackageID_3767872f-7dd0-488f-874b-b4869854989c': {'scan_status': 'DELIVERED',
#    'time_window': {'start_time_utc': '2018-07-27 16:00:00',
#     'end_time_utc': '2018-07-28 00:00:00'},
#    'planned_service_time_seconds': 47.6,
#    'dimensions': {'depth_cm': 39.5, 'height_cm': 22.2, 'width_cm': 35.6}},
#   'PackageID_9ce00272-37c9-4843-86fa-644144ba4903': {'scan_status': 'DELIVERED',
#    'time_window': {'start_time_utc': '2018-07-27 16:00:00',
#     'end_time_utc': '2018-07-28 00:00:00'},
#    'planned_service_time_seconds': 47.6,
#    'dimensions': {'depth_cm': 40.6, 'height_cm': 12.7, 'width_cm': 30.5}}},
#  'MO': {'PackageID_11ddcc55-e909-4216-9935-f396ec7b0aee': {'scan_status': 'DELIVERED',
#    'time_window': {'start_time_utc': nan, 'end_time_utc': nan},
#    'planned_service_time_seconds': 27.5,
#    'dimensions': {'depth_cm': 32.5, 'height_cm': 0.5, 'width_cm': 30.0}},
#   'PackageID_20e0e3d5-e902-4eaa-90a3-23bda0e956ff': {'scan_status': 'DELIVERED',
#    'time_window': {'start_time_utc': nan, 'end_time_utc': nan},
#    'planned_service_time_seconds': 27.5,
#    'dimensions': {'depth_cm': 34.3, 'height_cm': 11.4, 'width_cm': 26.7}},
#   'PackageID_e017b770-b799-40de-b76b-e0da39953239': {'scan_status': 'DELIVERED',
#    'time_window': {'start_time_utc': nan, 'end_time_utc': nan},
#    'planned_service_time_seconds': 27.5,
#    'dimensions': {'depth_cm': 25.4, 'height_cm': 12.7, 'width_cm': 17.8}},
#   'PackageID_9c4337fe-4fcd-44a3-a6d6-f2e63900c90a': {'scan_status': 'DELIVERED',
#    'time_window': {'start_time_utc': nan, 'end_time_utc': nan},
#    'planned_service_time_seconds': 27.5,
#    'dimensions': {'depth_cm': 25.4, 'height_cm': 7.6, 'width_cm': 17.8}}},
#  'MQ': {'PackageID_1616fc49-7d1c-42c8-8ad2-1fd5484f57a6': {'scan_status': 'DELIVERED',
#    'time_window': {'start_time_utc': nan, 'end_time_utc': nan},
#    'planned_service_time_seconds': 34.0,
#    'dimensions': {'depth_cm': 39.4, 'height_cm': 7.6, 'width_cm': 31.8}}},
#  'MR': {'PackageID_d167b61d-cbe1-435c-822b-2485a8241442': {'scan_status': 'DELIVERED',
#    'time_window': {'start_time_utc': nan, 'end_time_utc': nan},
#    'planned_service_time_seconds': 34.0,
#    'dimensions': {'depth_cm': 25.4, 'height_cm': 12.7, 'width_cm': 17.8}}},
#  'MW': {'PackageID_2b800bd6-ae76-4e2b-aa2c-ad5edcd3f82a': {'scan_status': 'DELIVERED',
#    'time_window': {'start_time_utc': nan, 'end_time_utc': nan},
#    'planned_service_time_seconds': 39.1,
#    'dimensions': {'depth_cm': 39.4, 'height_cm': 7.6, 'width_cm': 31.8}},
#   'PackageID_e8366ef5-d985-484a-998b-154f819a4833': {'scan_status': 'DELIVERED',
#    'time_window': {'start_time_utc': nan, 'end_time_utc': nan},
#    'planned_service_time_seconds': 39.1,
#    'dimensions': {'depth_cm': 28.5, 'height_cm': 4.5, 'width_cm': 26.0}},
#   'PackageID_c2ecbb2e-64a1-48f2-99c7-a56442fc1988': {'scan_status': 'DELIVERED',
#    'time_window': {'start_time_utc': nan, 'end_time_utc': nan},
#    'planned_service_time_seconds': 39.1,
#    'dimensions': {'depth_cm': 28.1, 'height_cm': 4.9, 'width_cm': 25.6}},
#   'PackageID_d0bf9184-d6e7-413d-93f4-0257a15eacd5': {'scan_status': 'DELIVERED',
#    'time_window': {'start_time_utc': nan, 'end_time_utc': nan},
#    'planned_service_time_seconds': 39.1,
#    'dimensions': {'depth_cm': 25.4, 'height_cm': 12.7, 'width_cm': 17.8}},
#   'PackageID_bb4e92b2-7b80-4933-9f1b-84d302e7d9fb': {'scan_status': 'DELIVERED',
#    'time_window': {'start_time_utc': nan, 'end_time_utc': nan},
#    'planned_service_time_seconds': 39.1,
#    'dimensions': {'depth_cm': 25.4, 'height_cm': 12.7, 'width_cm': 17.8}},
#   'PackageID_afdb8045-b9f6-4cdd-a829-8463a182e488': {'scan_status': 'DELIVERED',
#    'time_window': {'start_time_utc': nan, 'end_time_utc': nan},
#    'planned_service_time_seconds': 39.1,
#    'dimensions': {'depth_cm': 27.9, 'height_cm': 7.6, 'width_cm': 21.6}},
#   'PackageID_8ab261e1-00f0-4d8f-9116-6dd2aed9dfdd': {'scan_status': 'DELIVERED',
#    'time_window': {'start_time_utc': nan, 'end_time_utc': nan},
#    'planned_service_time_seconds': 39.1,
#    'dimensions': {'depth_cm': 45.7, 'height_cm': 21.6, 'width_cm': 22.9}},
#   'PackageID_fd4bee86-b692-4c9f-bdc2-5fb71b40be19': {'scan_status': 'DELIVERY_ATTEMPTED',
#    'time_window': {'start_time_utc': nan, 'end_time_utc': nan},
#    'planned_service_time_seconds': 39.1,
#    'dimensions': {'depth_cm': 31.5, 'height_cm': 1.5, 'width_cm': 29.0}},
#   'PackageID_23e8a25b-98b3-4787-a3d5-da6cdabe6e4d': {'scan_status': 'DELIVERED',
#    'time_window': {'start_time_utc': '2018-07-27 16:00:00',
#     'end_time_utc': '2018-07-28 00:00:00'},
#    'planned_service_time_seconds': 39.1,
#    'dimensions': {'depth_cm': 28.7, 'height_cm': 2.1, 'width_cm': 28.3}},
#   'PackageID_6dd1b2dd-dfea-4f18-8fa1-ddf93d87dde1': {'scan_status': 'DELIVERED',
#    'time_window': {'start_time_utc': '2018-07-27 16:00:00',
#     'end_time_utc': '2018-07-27 23:00:00'},
#    'planned_service_time_seconds': 39.1,
#    'dimensions': {'depth_cm': 21.8, 'height_cm': 3.6, 'width_cm': 14.2}},
#   'PackageID_8ae84d11-73b7-4ee2-ad37-5a61274b41f9': {'scan_status': 'DELIVERED',
#    'time_window': {'start_time_utc': nan, 'end_time_utc': nan},
#    'planned_service_time_seconds': 39.1,
#    'dimensions': {'depth_cm': 34.3, 'height_cm': 11.4, 'width_cm': 20.3}},
#   'PackageID_a946fdfb-cafc-4b86-8946-38826f65b43e': {'scan_status': 'DELIVERED',
#    'time_window': {'start_time_utc': nan, 'end_time_utc': nan},
#    'planned_service_time_seconds': 39.1,
#    'dimensions': {'depth_cm': 23.0, 'height_cm': 2.4, 'width_cm': 15.4}},
#   'PackageID_5b2db181-0a3d-4e02-8321-d274ef6b693e': {'scan_status': 'DELIVERED',
#    'time_window': {'start_time_utc': nan, 'end_time_utc': nan},
#    'planned_service_time_seconds': 39.1,
#    'dimensions': {'depth_cm': 65.5, 'height_cm': 6.5, 'width_cm': 24.5}},
#   'PackageID_8cd40921-d12f-4ea5-8abe-8677f03a3d25': {'scan_status': 'DELIVERED',
#    'time_window': {'start_time_utc': nan, 'end_time_utc': nan},
#    'planned_service_time_seconds': 39.1,
#    'dimensions': {'depth_cm': 34.3, 'height_cm': 7.6, 'width_cm': 24.1}},
#   'PackageID_fe911887-f82f-4227-bf23-bea99070eb99': {'scan_status': 'DELIVERED',
#    'time_window': {'start_time_utc': nan, 'end_time_utc': nan},
#    'planned_service_time_seconds': 39.1,
#    'dimensions': {'depth_cm': 34.3, 'height_cm': 7.6, 'width_cm': 24.1}},
#   'PackageID_790e4933-4dd1-4aa0-92a0-65805439641f': {'scan_status': 'DELIVERED',
#    'time_window': {'start_time_utc': nan, 'end_time_utc': nan},
#    'planned_service_time_seconds': 39.1,
#    'dimensions': {'depth_cm': 21.4, 'height_cm': 4.0, 'width_cm': 13.8}},
#   'PackageID_082e5daf-c8bf-45a5-8797-687091ea9636': {'scan_status': 'DELIVERED',
#    'time_window': {'start_time_utc': nan, 'end_time_utc': nan},
#    'planned_service_time_seconds': 39.1,
#    'dimensions': {'depth_cm': 27.9, 'height_cm': 5.1, 'width_cm': 25.4}},
#   'PackageID_72629b3d-1747-4675-9719-fe1ebbd718ef': {'scan_status': 'DELIVERED',
#    'time_window': {'start_time_utc': '2018-07-27 16:00:00',
#     'end_time_utc': '2018-07-28 00:00:00'},
#    'planned_service_time_seconds': 39.1,
#    'dimensions': {'depth_cm': 31.8, 'height_cm': 3.8, 'width_cm': 19.1}}},
#  'NE': {'PackageID_08529806-1b77-4394-9e58-056e97424f6b': {'scan_status': 'DELIVERED',
#    'time_window': {'start_time_utc': '2018-07-27 18:00:00',
#     'end_time_utc': '2018-07-28 00:00:00'},
#    'planned_service_time_seconds': 42.0,
#    'dimensions': {'depth_cm': 25.4, 'height_cm': 12.7, 'width_cm': 17.8}}},
#  'NL': {'PackageID_2d3fb06c-92f1-45b3-9b2d-06a4a3c6b308': {'scan_status': 'DELIVERED',
#    'time_window': {'start_time_utc': nan, 'end_time_utc': nan},
#    'planned_service_time_seconds': 39.0,
#    'dimensions': {'depth_cm': 25.4, 'height_cm': 7.6, 'width_cm': 17.8}},
#   'PackageID_7bd33076-48c8-48f7-a269-5d18ee34b794': {'scan_status': 'DELIVERED',
#    'time_window': {'start_time_utc': nan, 'end_time_utc': nan},
#    'planned_service_time_seconds': 39.0,
#    'dimensions': {'depth_cm': 30.5, 'height_cm': 4.3, 'width_cm': 22.9}},
#   'PackageID_e9e61e32-1332-498b-8923-789befdf3583': {'scan_status': 'DELIVERED',
#    'time_window': {'start_time_utc': nan, 'end_time_utc': nan},
#    'planned_service_time_seconds': 39.0,
#    'dimensions': {'depth_cm': 24.9, 'height_cm': 8.1, 'width_cm': 22.4}}},
#  'NM': {'PackageID_7ae9c524-806a-47e9-8bd5-880c4b9377ef': {'scan_status': 'DELIVERED',
#    'time_window': {'start_time_utc': nan, 'end_time_utc': nan},
#    'planned_service_time_seconds': 97.0,
#    'dimensions': {'depth_cm': 25.7, 'height_cm': 7.4, 'width_cm': 23.1}}},
#  'NR': {'PackageID_2e2da27e-bf40-4652-ab3d-ddc7e9f82e34': {'scan_status': 'DELIVERED',
#    'time_window': {'start_time_utc': nan, 'end_time_utc': nan},
#    'planned_service_time_seconds': 61.0,
#    'dimensions': {'depth_cm': 25.4, 'height_cm': 12.7, 'width_cm': 17.8}},
#   'PackageID_21720329-2fbf-4694-9051-cb126430b40d': {'scan_status': 'DELIVERED',
#    'time_window': {'start_time_utc': nan, 'end_time_utc': nan},
#    'planned_service_time_seconds': 61.0,
#    'dimensions': {'depth_cm': 53.3, 'height_cm': 38.1, 'width_cm': 45.7}}},
#  'NU': {'PackageID_3954074b-491d-4999-bd10-0d9100dc1f9b': {'scan_status': 'DELIVERED',
#    'time_window': {'start_time_utc': nan, 'end_time_utc': nan},
#    'planned_service_time_seconds': 56.0,
#    'dimensions': {'depth_cm': 25.4, 'height_cm': 12.7, 'width_cm': 17.8}}},
#  'PB': {'PackageID_49d21fba-a0e9-4610-b3a9-b23e1b912300': {'scan_status': 'DELIVERED',
#    'time_window': {'start_time_utc': nan, 'end_time_utc': nan},
#    'planned_service_time_seconds': 32.0,
#    'dimensions': {'depth_cm': 34.3, 'height_cm': 11.4, 'width_cm': 20.3}}},
#  'PJ': {'PackageID_f10e4c7f-ff0b-4a2d-a307-b6ede6f7d487': {'scan_status': 'DELIVERED',
#    'time_window': {'start_time_utc': nan, 'end_time_utc': nan},
#    'planned_service_time_seconds': 79.2,
#    'dimensions': {'depth_cm': 25.4, 'height_cm': 12.7, 'width_cm': 17.8}},
#   'PackageID_7e96105e-c9f1-4e28-877c-4f9f65de1d4c': {'scan_status': 'DELIVERED',
#    'time_window': {'start_time_utc': nan, 'end_time_utc': nan},
#    'planned_service_time_seconds': 79.2,
#    'dimensions': {'depth_cm': 34.3, 'height_cm': 7.6, 'width_cm': 24.1}},
#   'PackageID_f8f63969-8640-4cc1-8637-4d8d1c499081': {'scan_status': 'DELIVERED',
#    'time_window': {'start_time_utc': nan, 'end_time_utc': nan},
#    'planned_service_time_seconds': 79.2,
#    'dimensions': {'depth_cm': 40.6, 'height_cm': 12.7, 'width_cm': 30.5}},
#   'PackageID_3daa9e75-9a36-42ca-8cd8-d38978df2586': {'scan_status': 'DELIVERED',
#    'time_window': {'start_time_utc': nan, 'end_time_utc': nan},
#    'planned_service_time_seconds': 79.2,
#    'dimensions': {'depth_cm': 43.2, 'height_cm': 7.6, 'width_cm': 27.9}},
#   'PackageID_dedc9657-93e4-45bf-a2dd-1c744e4cb2ba': {'scan_status': 'DELIVERED',
#    'time_window': {'start_time_utc': nan, 'end_time_utc': nan},
#    'planned_service_time_seconds': 79.2,
#    'dimensions': {'depth_cm': 54.0, 'height_cm': 12.4, 'width_cm': 41.3}},
#   'PackageID_a4fca531-1e79-4f3c-a2e2-2131d69d326b': {'scan_status': 'DELIVERED',
#    'time_window': {'start_time_utc': nan, 'end_time_utc': nan},
#    'planned_service_time_seconds': 79.2,
#    'dimensions': {'depth_cm': 36.8, 'height_cm': 17.8, 'width_cm': 20.3}}},
#  'PS': {'PackageID_7e6991d2-1fde-471c-811b-0dc213b965ab': {'scan_status': 'DELIVERED',
#    'time_window': {'start_time_utc': nan, 'end_time_utc': nan},
#    'planned_service_time_seconds': 48.0,
#    'dimensions': {'depth_cm': 30.5, 'height_cm': 10.2, 'width_cm': 19.1}},
#   'PackageID_d0e2a972-ce02-4be6-b276-54608621597f': {'scan_status': 'DELIVERED',
#    'time_window': {'start_time_utc': nan, 'end_time_utc': nan},
#    'planned_service_time_seconds': 48.0,
#    'dimensions': {'depth_cm': 27.9, 'height_cm': 5.1, 'width_cm': 25.4}},
# ...
#  'TK': {'PackageID_128ad087-b878-4b06-88e5-6ffff4a2d8cf': {'scan_status': 'DELIVERED',
#    'time_window': {'start_time_utc': nan, 'end_time_utc': nan},
#    'planned_service_time_seconds': 88.0,
#    'dimensions': {'depth_cm': 24.1, 'height_cm': 4.3, 'width_cm': 16.5}}},
#  'TQ': {'PackageID_06b20b47-d8b2-44ea-9ec4-1a5d8fa0e1f6': {'scan_status': 'DELIVERED',
#    'time_window': {'start_time_utc': nan, 'end_time_utc': nan},
#    'planned_service_time_seconds': 32.2,
#    'dimensions': {'depth_cm': 39.4, 'height_cm': 7.6, 'width_cm': 31.8}},
#   'PackageID_052cc966-feab-4542-a246-b0ebfcfa11d2': {'scan_status': 'DELIVERED',
#    'time_window': {'start_time_utc': nan, 'end_time_utc': nan},
#    'planned_service_time_seconds': 32.2,
#    'dimensions': {'depth_cm': 30.0, 'height_cm': 5.6, 'width_cm': 17.3}},
#   'PackageID_177390af-0e50-4e73-8c95-fedbf4439a0c': {'scan_status': 'DELIVERED',
#    'time_window': {'start_time_utc': nan, 'end_time_utc': nan},
#    'planned_service_time_seconds': 32.2,
#    'dimensions': {'depth_cm': 34.3, 'height_cm': 7.6, 'width_cm': 24.1}},
#   'PackageID_880ec0aa-86d3-46fe-ad4c-9d3da78ee9a3': {'scan_status': 'DELIVERED',
#    'time_window': {'start_time_utc': nan, 'end_time_utc': nan},
#    'planned_service_time_seconds': 32.2,
#    'dimensions': {'depth_cm': 36.8, 'height_cm': 17.8, 'width_cm': 20.3}}},
#  'TY': {'PackageID_e223fd6e-0dd1-4d35-b9cc-ebbbb0d46bb3': {'scan_status': 'DELIVERED',
#    'time_window': {'start_time_utc': nan, 'end_time_utc': nan},
#    'planned_service_time_seconds': 35.6,
#    'dimensions': {'depth_cm': 27.0, 'height_cm': 6.0, 'width_cm': 24.5}},
#   'PackageID_6c068a6d-0d9c-48e9-b162-19e47080a700': {'scan_status': 'DELIVERED',
#    'time_window': {'start_time_utc': nan, 'end_time_utc': nan},
#    'planned_service_time_seconds': 35.6,
#    'dimensions': {'depth_cm': 35.8, 'height_cm': 7.4, 'width_cm': 20.6}},
#   'PackageID_1f634697-bc37-4e99-be99-ec1e555844a3': {'scan_status': 'DELIVERED',
#    'time_window': {'start_time_utc': nan, 'end_time_utc': nan},
#    'planned_service_time_seconds': 35.6,
#    'dimensions': {'depth_cm': 30.5, 'height_cm': 10.2, 'width_cm': 19.1}},
#   'PackageID_64f95a30-7ac7-427e-9b86-bd18252329cb': {'scan_status': 'DELIVERED',
#    'time_window': {'start_time_utc': nan, 'end_time_utc': nan},
#    'planned_service_time_seconds': 35.6,
#    'dimensions': {'depth_cm': 48.3, 'height_cm': 15.2, 'width_cm': 33.0}},
#   'PackageID_414f80d9-ca8b-4842-8052-b3ad30529416': {'scan_status': 'DELIVERED',
#    'time_window': {'start_time_utc': nan, 'end_time_utc': nan},
#    'planned_service_time_seconds': 35.6,
#    'dimensions': {'depth_cm': 35.6, 'height_cm': 7.6, 'width_cm': 20.3}}},
#  'UI': {'PackageID_fedc0315-d669-4033-8a27-3a88210c7356': {'scan_status': 'DELIVERED',
#    'time_window': {'start_time_utc': '2018-07-27 16:00:00',
#     'end_time_utc': '2018-07-28 00:00:00'},
#    'planned_service_time_seconds': 30.7,
#    'dimensions': {'depth_cm': 50.5, 'height_cm': 5.6, 'width_cm': 43.4}},
#   'PackageID_ef8e16c7-fbd3-40b7-8f42-749916b10c8e': {'scan_status': 'DELIVERED',
#    'time_window': {'start_time_utc': '2018-07-27 16:00:00',
#     'end_time_utc': '2018-07-28 00:00:00'},
#    'planned_service_time_seconds': 30.7,
#    'dimensions': {'depth_cm': 48.3, 'height_cm': 15.2, 'width_cm': 33.0}},
#   'PackageID_c71ad0f4-b2a0-47b6-9e16-c2285d567a39': {'scan_status': 'DELIVERED',
#    'time_window': {'start_time_utc': '2018-07-27 16:00:00',
#     'end_time_utc': '2018-07-28 00:00:00'},
#    'planned_service_time_seconds': 30.7,
#    'dimensions': {'depth_cm': 35.6, 'height_cm': 22.9, 'width_cm': 31.8}}},
#  'UJ': {'PackageID_c6c16d7d-384d-417b-a9dc-4cc4fc4fa4a6': {'scan_status': 'DELIVERED',
#    'time_window': {'start_time_utc': '2018-07-27 16:00:00',
#     'end_time_utc': '2018-07-27 23:00:00'},
#    'planned_service_time_seconds': 88.0,
#    'dimensions': {'depth_cm': 34.3, 'height_cm': 11.4, 'width_cm': 26.7}}},
#  'UN': {'PackageID_90d428b5-d771-4009-8e37-1e8e9342c12b': {'scan_status': 'DELIVERED',
#    'time_window': {'start_time_utc': nan, 'end_time_utc': nan},
#    'planned_service_time_seconds': 19.0,
#    'dimensions': {'depth_cm': 34.3, 'height_cm': 7.6, 'width_cm': 24.1}},
#   'PackageID_ea68e4cd-e9b8-48cb-a769-f0f34e28c6ff': {'scan_status': 'DELIVERED',
#    'time_window': {'start_time_utc': nan, 'end_time_utc': nan},
#    'planned_service_time_seconds': 19.0,
#    'dimensions': {'depth_cm': 20.6, 'height_cm': 4.3, 'width_cm': 17.5}},
#   'PackageID_9a2e3c33-5cdc-488f-9c97-f8ac9387a847': {'scan_status': 'DELIVERED',
#    'time_window': {'start_time_utc': nan, 'end_time_utc': nan},
#    'planned_service_time_seconds': 19.0,
#    'dimensions': {'depth_cm': 30.0, 'height_cm': 3.0, 'width_cm': 27.5}},
#   'PackageID_207e7aa5-f2e7-461d-82fc-99fd3da55189': {'scan_status': 'DELIVERED',
#    'time_window': {'start_time_utc': nan, 'end_time_utc': nan},
#    'planned_service_time_seconds': 19.0,
#    'dimensions': {'depth_cm': 31.7, 'height_cm': 1.3, 'width_cm': 29.2}}},
#  'UR': {'PackageID_45071e44-0476-4a72-8dd2-b7205e50a207': {'scan_status': 'DELIVERED',
#    'time_window': {'start_time_utc': nan, 'end_time_utc': nan},
#    'planned_service_time_seconds': 32.3,
#    'dimensions': {'depth_cm': 22.7, 'height_cm': 2.7, 'width_cm': 15.1}},
#   'PackageID_71f03330-9a21-4765-b825-76593d6ada90': {'scan_status': 'DELIVERED',
#    'time_window': {'start_time_utc': nan, 'end_time_utc': nan},
#    'planned_service_time_seconds': 32.3,
#    'dimensions': {'depth_cm': 36.8, 'height_cm': 17.8, 'width_cm': 20.3}},
#   'PackageID_24ff8e6c-5047-409d-ad18-20e3408adaaf': {'scan_status': 'DELIVERED',
#    'time_window': {'start_time_utc': nan, 'end_time_utc': nan},
#    'planned_service_time_seconds': 32.3,
#    'dimensions': {'depth_cm': 33.3, 'height_cm': 2.3, 'width_cm': 20.6}}},
#  'US': {'PackageID_353bf69c-aeb1-4884-85f3-d47936ba5abc': {'scan_status': 'DELIVERED',
#    'time_window': {'start_time_utc': '2018-07-27 16:00:00',
#     'end_time_utc': '2018-07-28 00:00:00'},
#    'planned_service_time_seconds': 150.0,
#    'dimensions': {'depth_cm': 21.8, 'height_cm': 3.6, 'width_cm': 14.2}}},
#  'UU': {'PackageID_7bd12dc4-e264-4b45-bea3-454653c6d68c': {'scan_status': 'DELIVERED',
#    'time_window': {'start_time_utc': nan, 'end_time_utc': nan},
#    'planned_service_time_seconds': 80.0,
#    'dimensions': {'depth_cm': 39.4, 'height_cm': 3.8, 'width_cm': 24.1}}},
#  'UW': {'PackageID_f5a90408-4256-4b81-a1eb-79108acf4c6f': {'scan_status': 'DELIVERED',
#    'time_window': {'start_time_utc': nan, 'end_time_utc': nan},
#    'planned_service_time_seconds': 52.5,
#    'dimensions': {'depth_cm': 32.3, 'height_cm': 0.8, 'width_cm': 29.7}},
#   'PackageID_f45fc3f7-a48a-4b74-9093-b6a0d45abee1': {'scan_status': 'DELIVERED',
#    'time_window': {'start_time_utc': nan, 'end_time_utc': nan},
#    'planned_service_time_seconds': 52.5,
#    'dimensions': {'depth_cm': 25.1, 'height_cm': 7.9, 'width_cm': 22.6}}},
#  'VA': {'PackageID_867155cb-028e-42e8-b246-e64e3d441762': {'scan_status': 'DELIVERED',
#    'time_window': {'start_time_utc': nan, 'end_time_utc': nan},
#    'planned_service_time_seconds': 76.0,
#    'dimensions': {'depth_cm': 35.6, 'height_cm': 22.9, 'width_cm': 31.8}}},
#  'VC': {'PackageID_bcf9e9f6-388d-4ba0-9333-93f081b7c1e4': {'scan_status': 'DELIVERED',
#    'time_window': {'start_time_utc': nan, 'end_time_utc': nan},
#    'planned_service_time_seconds': 47.0,
#    'dimensions': {'depth_cm': 49.5, 'height_cm': 7.6, 'width_cm': 35.6}}},
#  'VE': {},
#  'VW': {'PackageID_a50c6886-ae6b-4ccc-ba32-c80833309774': {'scan_status': 'DELIVERED',
#    'time_window': {'start_time_utc': nan, 'end_time_utc': nan},
#    'planned_service_time_seconds': 15.0,
#    'dimensions': {'depth_cm': 35.6, 'height_cm': 6.6, 'width_cm': 22.9}}},
#  'WJ': {'PackageID_04338da1-9944-4509-98d0-4c053e1e28f4': {'scan_status': 'DELIVERED',
#    'time_window': {'start_time_utc': nan, 'end_time_utc': nan},
#    'planned_service_time_seconds': 89.0,
#    'dimensions': {'depth_cm': 26.7, 'height_cm': 6.3, 'width_cm': 24.2}}},
#  'WS': {'PackageID_e5c5d43b-f116-42f1-8a8b-a9fa9f91837c': {'scan_status': 'DELIVERED',
#    'time_window': {'start_time_utc': nan, 'end_time_utc': nan},
#    'planned_service_time_seconds': 17.2,
#    'dimensions': {'depth_cm': 30.5, 'height_cm': 10.2, 'width_cm': 19.1}},
#   'PackageID_62b22f4d-5dfa-4684-9aba-cac3f0238533': {'scan_status': 'DELIVERED',
#    'time_window': {'start_time_utc': nan, 'end_time_utc': nan},
#    'planned_service_time_seconds': 17.2,
#    'dimensions': {'depth_cm': 45.7, 'height_cm': 21.6, 'width_cm': 22.9}},
#   'PackageID_49df9eb0-fbe9-4af9-a40a-d179f946b616': {'scan_status': 'DELIVERED',
#    'time_window': {'start_time_utc': nan, 'end_time_utc': nan},
#    'planned_service_time_seconds': 17.2,
#    'dimensions': {'depth_cm': 34.3, 'height_cm': 7.6, 'width_cm': 24.1}},
#   'PackageID_8f451c55-af4a-4100-922a-3acd3dffc831': {'scan_status': 'DELIVERED',
#    'time_window': {'start_time_utc': nan, 'end_time_utc': nan},
#    'planned_service_time_seconds': 17.2,
#    'dimensions': {'depth_cm': 24.9, 'height_cm': 5.8, 'width_cm': 14.7}}},
#  'XB': {'PackageID_3e70fe6a-31a5-4bd2-b1f6-9ce658b7bf36': {'scan_status': 'DELIVERED',
#    'time_window': {'start_time_utc': nan, 'end_time_utc': nan},
#    'planned_service_time_seconds': 48.0,
#    'dimensions': {'depth_cm': 25.4, 'height_cm': 7.6, 'width_cm': 17.8}},
#   'PackageID_65f73255-85aa-42c5-8a32-5f98a85c3095': {'scan_status': 'DELIVERED',
#    'time_window': {'start_time_utc': nan, 'end_time_utc': nan},
#    'planned_service_time_seconds': 48.0,
#    'dimensions': {'depth_cm': 36.2, 'height_cm': 27.9, 'width_cm': 28.6}}},
#  'XD': {'PackageID_bff9965d-60ce-4386-b981-2a5b5ce391ae': {'scan_status': 'DELIVERED',
#    'time_window': {'start_time_utc': nan, 'end_time_utc': nan},
#    'planned_service_time_seconds': 26.0,
#    'dimensions': {'depth_cm': 29.5, 'height_cm': 6.1, 'width_cm': 16.8}}},
#  'YE': {'PackageID_f9b8491a-8abd-4acb-ac23-0ccca4c48d6f': {'scan_status': 'DELIVERED',
#    'time_window': {'start_time_utc': nan, 'end_time_utc': nan},
#    'planned_service_time_seconds': 48.0,
#    'dimensions': {'depth_cm': 35.6, 'height_cm': 22.9, 'width_cm': 31.8}}},
#  'YH': {'PackageID_0a82dfc2-5a4f-482c-b436-b777c3afbba6': {'scan_status': 'DELIVERED',
#    'time_window': {'start_time_utc': nan, 'end_time_utc': nan},
#    'planned_service_time_seconds': 24.0,
#    'dimensions': {'depth_cm': 27.9, 'height_cm': 7.6, 'width_cm': 21.6}}},
#  'YJ': {'PackageID_c4159bfc-c103-4027-9352-2f348d660c72': {'scan_status': 'DELIVERED',
#    'time_window': {'start_time_utc': nan, 'end_time_utc': nan},
#    'planned_service_time_seconds': 75.3,
#    'dimensions': {'depth_cm': 36.8, 'height_cm': 17.8, 'width_cm': 20.3}},
#   'PackageID_a452d13d-5cee-4b65-91c9-e5e770faf98e': {'scan_status': 'DELIVERED',
#    'time_window': {'start_time_utc': nan, 'end_time_utc': nan},
#    'planned_service_time_seconds': 75.3,
#    'dimensions': {'depth_cm': 24.8, 'height_cm': 0.6, 'width_cm': 17.2}},
#   'PackageID_5d66eac1-8007-46f5-8f26-52e6cf38ee87': {'scan_status': 'DELIVERED',
#    'time_window': {'start_time_utc': nan, 'end_time_utc': nan},
#    'planned_service_time_seconds': 75.3,
#    'dimensions': {'depth_cm': 25.4, 'height_cm': 7.6, 'width_cm': 17.8}}},
#  'YN': {'PackageID_ab52b4f7-91f3-4042-b3eb-4f5f49385287': {'scan_status': 'DELIVERED',
#    'time_window': {'start_time_utc': nan, 'end_time_utc': nan},
#    'planned_service_time_seconds': 40.0,
#    'dimensions': {'depth_cm': 39.4, 'height_cm': 7.6, 'width_cm': 31.8}},
#   'PackageID_b764304d-5304-4ab2-b30d-229e9da3936d': {'scan_status': 'DELIVERED',
#    'time_window': {'start_time_utc': nan, 'end_time_utc': nan},
#    'planned_service_time_seconds': 40.0,
#    'dimensions': {'depth_cm': 40.6, 'height_cm': 12.7, 'width_cm': 30.5}}},
#  'YR': {'PackageID_11f388b4-b235-4e11-9a21-6b6bb629c43b': {'scan_status': 'DELIVERED',
#    'time_window': {'start_time_utc': nan, 'end_time_utc': nan},
#    'planned_service_time_seconds': 39.0,
#    'dimensions': {'depth_cm': 48.3, 'height_cm': 15.2, 'width_cm': 33.0}}},
#  'YY': {'PackageID_b0d1fb66-7c97-402f-a061-4cf0708585f1': {'scan_status': 'DELIVERED',
#    'time_window': {'start_time_utc': nan, 'end_time_utc': nan},
#    'planned_service_time_seconds': 21.0,
#    'dimensions': {'depth_cm': 61.6, 'height_cm': 33.0, 'width_cm': 41.3}},
#   'PackageID_acb1b59d-025c-4281-b82d-afe6c3f82d59': {'scan_status': 'DELIVERED',
#    'time_window': {'start_time_utc': nan, 'end_time_utc': nan},
#    'planned_service_time_seconds': 21.0,
#    'dimensions': {'depth_cm': 32.6, 'height_cm': 3.0, 'width_cm': 19.9}},
#   'PackageID_9a64edab-7212-4c6d-a1df-0f8f9101b196': {'scan_status': 'DELIVERED',
#    'time_window': {'start_time_utc': nan, 'end_time_utc': nan},
#    'planned_service_time_seconds': 21.0,
#    'dimensions': {'depth_cm': 34.3, 'height_cm': 7.6, 'width_cm': 24.1}},
#   'PackageID_ada83486-1163-4349-837e-74fa336d6ee6': {'scan_status': 'DELIVERED',
#    'time_window': {'start_time_utc': nan, 'end_time_utc': nan},
#    'planned_service_time_seconds': 21.0,
#    'dimensions': {'depth_cm': 40.6, 'height_cm': 12.7, 'width_cm': 30.5}},
#   'PackageID_c0633803-0d93-4396-b7b0-60d098b6af48': {'scan_status': 'DELIVERED',
#    'time_window': {'start_time_utc': nan, 'end_time_utc': nan},
#    'planned_service_time_seconds': 21.0,
#    'dimensions': {'depth_cm': 32.3, 'height_cm': 3.3, 'width_cm': 19.6}}},
#  'ZB': {'PackageID_61bad700-eb7d-4188-bf80-3e52635bde34': {'scan_status': 'DELIVERED',
#    'time_window': {'start_time_utc': nan, 'end_time_utc': nan},
#    'planned_service_time_seconds': 41.4,
#    'dimensions': {'depth_cm': 32.2, 'height_cm': 0.8, 'width_cm': 29.7}},
#   'PackageID_d6b81236-1a5d-47b2-9bd4-f68afab79ef9': {'scan_status': 'DELIVERED',
#    'time_window': {'start_time_utc': nan, 'end_time_utc': nan},
#    'planned_service_time_seconds': 41.4,
#    'dimensions': {'depth_cm': 27.2, 'height_cm': 5.8, 'width_cm': 24.7}},
#   'PackageID_58ce99fe-8d73-4d7e-a76c-0c001ba5f54e': {'scan_status': 'DELIVERED',
#    'time_window': {'start_time_utc': nan, 'end_time_utc': nan},
#    'planned_service_time_seconds': 41.4,
#    'dimensions': {'depth_cm': 27.9, 'height_cm': 5.1, 'width_cm': 25.4}},
#   'PackageID_d2502e59-812b-4887-b7a3-463411086cf0': {'scan_status': 'DELIVERED',
#    'time_window': {'start_time_utc': nan, 'end_time_utc': nan},
#    'planned_service_time_seconds': 41.4,
#    'dimensions': {'depth_cm': 31.2, 'height_cm': 11.9, 'width_cm': 16.0}},
#   'PackageID_9979dfe6-f1b0-4322-bd70-3f734d5b5cea': {'scan_status': 'DELIVERED',
#    'time_window': {'start_time_utc': nan, 'end_time_utc': nan},
#    'planned_service_time_seconds': 41.4,
#    'dimensions': {'depth_cm': 43.2, 'height_cm': 7.6, 'width_cm': 27.9}}},
#  'ZE': {'PackageID_8a0877d7-29ee-4549-9431-d72e4d04dcd6': {'scan_status': 'DELIVERED',
#    'time_window': {'start_time_utc': nan, 'end_time_utc': nan},
#    'planned_service_time_seconds': 88.0,
#    'dimensions': {'depth_cm': 34.3, 'height_cm': 11.4, 'width_cm': 26.7}}},
#  'ZP': {'PackageID_ddae9570-08ee-4204-a7f3-5d0f472788d9': {'scan_status': 'DELIVERED',
#    'time_window': {'start_time_utc': '2018-07-27 16:00:00',
#     'end_time_utc': '2018-07-28 00:00:00'},
#    'planned_service_time_seconds': 18.0,
#    'dimensions': {'depth_cm': 25.4, 'height_cm': 7.6, 'width_cm': 17.8}}},
#  'ZU': {'PackageID_03f1bbbd-370c-4b9c-8b26-c7d34bbef6f1': {'scan_status': 'DELIVERED',
#    'time_window': {'start_time_utc': '2018-07-27 16:00:00',
#     'end_time_utc': '2018-07-28 00:00:00'},
#    'planned_service_time_seconds': 30.7,
#    'dimensions': {'depth_cm': 23.1, 'height_cm': 2.3, 'width_cm': 15.5}},
#   'PackageID_1b89ed78-54bf-475a-aa62-f6bcabc5f510': {'scan_status': 'DELIVERED',
#    'time_window': {'start_time_utc': '2018-07-27 16:00:00',
#     'end_time_utc': '2018-07-28 00:00:00'},
#    'planned_service_time_seconds': 30.7,
#    'dimensions': {'depth_cm': 30.5, 'height_cm': 5.1, 'width_cm': 17.8}},
#   'PackageID_f89e7970-f887-4479-9bb5-f45f4484d15a': {'scan_status': 'DELIVERED',
#    'time_window': {'start_time_utc': nan, 'end_time_utc': nan},
#    'planned_service_time_seconds': 30.7,
#    'dimensions': {'depth_cm': 36.8, 'height_cm': 17.8, 'width_cm': 20.3}}},
#  'package_name': 'amazon-routing-challenge'}

# %% [markdown]
# ## Create the Route DataFrame

# %%
with open(os.path.join(data_path, "route_data.json"), "r") as f:
    route_data = json.load(f)

# %%
len(route_data)
# Out:
# 6112

# %%
route_df = pd.DataFrame.from_records(
    (
        {
            "stop_id": k,
            "route_id": route_id,
            "station_code": route_data[route_id]["station_code"],
            "departure_datetime": route_data[route_id]["date_YYYY_MM_DD"] + " " + route_data[route_id]["departure_time_utc"],
            "executor_capacity_cm3": route_data[route_id]["executor_capacity_cm3"],
            "route_score": route_data[route_id]["route_score"],
            **v,
        }
        for route_id in route_data.keys()
        for k, v in route_data[route_id]["stops"].items()
    )
)

# %% [markdown]
# ## Open the Sequence Data

# %%
with open(os.path.join(data_path, "actual_sequences.json"), "r") as f:
    actual_sequences = json.load(f)

# %%
sequential_pairs = {}

for k in actual_sequences.keys():
    _t = [v[0] for v in sorted(tuple(actual_sequences[k]['actual'].items()), key=lambda x: x[1])]
    sequential_pairs[k] = tuple(zip(_t, _t[1:]))

# %% [markdown]
# ## Investigate the Stations

# %%
route_df["station_code"].unique()
# Out:
# array(['DLA3', 'DSE4', 'DSE5', 'DLA9', 'DLA7', 'DCH4', 'DBO2', 'DBO3',
#        'DLA8', 'DLA5', 'DCH3', 'DCH1', 'DAU1', 'DCH2', 'DLA4', 'DSE2',
#        'DBO1'], dtype=object)

# %% [markdown]
# ## Number of Routes Missing Zone ID

# %% [markdown]
# All papers (except 1) solve by replacing missing Zone ID with euclidean distance nearest zone id

# %%
bad_routes = route_df.loc[
    ((route_df.zone_id.isna()) & (route_df.type != "Station"))
    | (route_df.lat.isna() | route_df.lng.isna())
    # | (route_df.route_score != "High")
].route_id.unique()
len(bad_routes)
# Out:
# 2544

# %%
good_route_df = route_df.copy() # loc[~route_df.route_id.isin(bad_routes)].copy()
len(good_route_df.route_id.unique())
# Out:
# 6112

# %%
_dup_stops = good_route_df.groupby(["lat", "lng"]).agg({"route_id": "nunique"})
_dup_stops.head()
# Out:
#                       route_id
# lat       lng
# 30.117288 -97.968165         1
# 30.118834 -97.988569         1
# 30.119146 -97.983968         1
# 30.120233 -97.983939         1
# 30.120723 -97.983840         1

# %%
_dup_stops.loc[(_dup_stops.route_id > 1)]
# Out:
#                        route_id
# lat       lng
# 30.129676 -97.963750          2
# 30.132366 -97.965042          2
# 30.136697 -97.960858          3
# 30.136878 -97.968069          2
# 30.137279 -97.961708          2
# ...                         ...
# 48.125239 -122.157453         2
# 48.125886 -122.143153         2
# 48.127115 -122.155157         2
# 48.127870 -122.159378         2
# 48.128237 -122.158439         2
#
# [128839 rows x 1 columns]

# %% [markdown]
# ### Calculate the Datetime Specifics

# %%
good_route_df.departure_datetime = pd.to_datetime(good_route_df.departure_datetime)
# good_route_df.sort_values(by="departure_datetime", inplace=True)
good_route_df.departure_datetime.min(), good_route_df.departure_datetime.max()
# Out:
# (Timestamp('2018-07-19 13:41:42'), Timestamp('2018-08-26 16:14:30'))

# %% [markdown]
# ### Plotting where the Stations are at

# %%
fig = go.Figure()

_filtered_df = good_route_df.loc[good_route_df["type"] == "Station"]


for station_code in _filtered_df["station_code"].unique():
    _df = _filtered_df.loc[_filtered_df["station_code"] == station_code]
    fig.add_trace(
        go.Scattermapbox(
            name=station_code,
            lat=[_df["lat"].mean()],
            lon=[_df["lng"].mean()],
            mode="markers",
            marker=dict(
                size=10,
            ),
            text=_df["station_code"],
            textfont=dict(
                family="sans serif",
                size=22,
            ),
        )
    )

fig.update_layout(
    # autosize=True,
    height=600,
    width=1000,
    hovermode="closest",
    mapbox=go.layout.Mapbox(
        accesstoken=os.environ["MAPBOX_KEY"],
        style="mapbox://styles/max-schrader/ck8t1cmmc02wk1it9rv28iyte",
        # style="mapbox://styles/max-schrader/cl6lhvrfw001516pkh3s6iv7l",
        bearing=0,
        center=go.layout.mapbox.Center(
            lat=_filtered_df["lat"].mean(), lon=_filtered_df["lng"].mean()
        ),
        pitch=0,
        zoom=2,
    ),
    # margin=go.layout.Margin(l=0, r=0, t=0, b=0),
)

# %% [markdown]
# ### Creating a Route ID to Station ID Dictionary

# %%
station_route_id = dict(good_route_df.loc[good_route_df["type"] == "Station"][["route_id", "stop_id"]].values)

# %% [markdown]
# ## Investigating Duplicate Dropoffs

# %%
good_route_df["duplicates"] = good_route_df.duplicated(
    subset=["lat", "lng"], keep=False
)

# %%
good_route_df["duplicates"] = good_route_df.duplicated(
    subset=["lat", "lng"], keep=False
) #& (good_route_df.type != "Station")


lat_lon_dup = good_route_df.loc[good_route_df.duplicates].groupby(["lat", "lng"])['route_id'].unique().reset_index()
# lat_lon_dup.iloc[10].route_id

# %%
lat_lon_dup.route_id = lat_lon_dup.route_id.apply(lambda x: tuple(x))

# %%
lat_lon_dup
# Out:
#               lat         lng  \
# 0       30.129676  -97.963750
# 1       30.132366  -97.965042
# 2       30.136697  -97.960858
# 3       30.136878  -97.968069
# 4       30.137279  -97.961708
# ...           ...         ...
# 129952  48.125239 -122.157453
# 129953  48.125886 -122.143153
# 129954  48.127115 -122.155157
# 129955  48.127870 -122.159378
# 129956  48.128237 -122.158439
#
#                                                  route_id
# 0       (RouteID_9ea87ee2-867b-4cc0-ab72-f76d8389182a,...
# 1       (RouteID_5ab24a12-62bf-4b91-9b49-3be9c3509b7b,...
# 2       (RouteID_5ab24a12-62bf-4b91-9b49-3be9c3509b7b,...
# 3       (RouteID_c8a6bb25-32bd-424a-93eb-46e9261ae1e9,...
# 4       (RouteID_9ea87ee2-867b-4cc0-ab72-f76d8389182a,...
# ...                                                   ...
# 129952  (RouteID_5588756f-5963-424d-ada6-cf0fb77c82cd,...
# 129953  (RouteID_076b21cf-9d76-4d57-9859-cf3fb783533f,...
# 129954  (RouteID_076b21cf-9d76-4d57-9859-cf3fb783533f,...
# 129955  (RouteID_5588756f-5963-424d-ada6-cf0fb77c82cd,...
# 129956  (RouteID_076b21cf-9d76-4d57-9859-cf3fb783533f,...
#
# [129957 rows x 3 columns]

# %%
lat_lon_map = {}

def create_map(row):
    for route_id in row.route_id:
        if route_id not in lat_lon_map:
            lat_lon_map[route_id] = []
        lat_lon_map[route_id].append(tuple(row[['lat', 'lng']]))

_ = lat_lon_dup.apply(
    create_map, axis=1
)

for route_id in lat_lon_map:
    lat_lon_map[route_id] = list(set(lat_lon_map[route_id]))

# %% [markdown]
# ### Create a DataFrame with the matched pairs

# %%
import itertools

# %%
match_pairs = []

# this isn't computationaly efficient, but it's a small enough dataset that doesn't matter
covered_pairs = set()
for r_1 in lat_lon_map:
        match_pairs.extend((r_1, *match_location)
                           for match_location in itertools.product(
                               lat_lon_map[r_1], lat_lon_map[r_1])
                           if match_location[0] != match_location[1])
    # lat_lon_map[r_1]

# %%
tt_df = pd.DataFrame(match_pairs, columns=["route_id", "from", "to"])
_loc_pairs = tt_df.groupby(["from", "to"]).agg({"route_id": "nunique"}).reset_index()
# keep only the ones that have more than one route
_loc_pairs = _loc_pairs.loc[_loc_pairs.route_id > 1]
_loc_pairs.head()
# Out:
#                       from                       to  route_id
# 1   (30.129676, -97.96375)  (30.136697, -97.960858)         2
# 2   (30.129676, -97.96375)  (30.137279, -97.961708)         2
# 3   (30.129676, -97.96375)  (30.137574, -97.957124)         2
# 10  (30.129676, -97.96375)   (30.152141, -97.95341)         2
# 18  (30.129676, -97.96375)  (30.156254, -97.948389)         2

# %%
okay_tuples = tuple(tuple(v) for v in _loc_pairs[['to', 'from']].itertuples(index=False))

# %%
tt_df = tt_df.loc[tt_df[['from', 'to']].apply(tuple, axis=1).isin(okay_tuples)].reset_index(drop=True)

# %% [markdown]
# #### Add Information to the DF

# %%
# build a map of id -> lat, lon -> stop_id
lat_lon_2_id = {r_id: {
    (stop_info['lat'], stop_info['lng']): stop_id for stop_id, stop_info in r_data['stops'].items()
} for r_id, r_data in route_data.items()}

# build a map of route_id -> depature_datetime
route_id_2_departure_datetime = good_route_df.groupby('route_id').first()['departure_datetime'].to_dict()

# %%
# find the matching stop id for each route
def to_stop_id(row, ):
    return lat_lon_2_id[row[0]].get(row[1])

tt_df['from_id'] = tt_df[['route_id', 'from']].apply(to_stop_id, axis=1, raw=True)
tt_df['to_id'] = tt_df[['route_id', 'to']].apply(to_stop_id, axis=1, raw=True)
tt_df['datetime'] = tt_df['route_id'].apply(lambda x: route_id_2_departure_datetime[x])

# %%
tt_df.head()
# Out:
#                                        route_id                     from  \
# 0  RouteID_9ea87ee2-867b-4cc0-ab72-f76d8389182a  (30.186342, -97.925433)
# 1  RouteID_9ea87ee2-867b-4cc0-ab72-f76d8389182a  (30.186342, -97.925433)
# 2  RouteID_9ea87ee2-867b-4cc0-ab72-f76d8389182a  (30.186342, -97.925433)
# 3  RouteID_9ea87ee2-867b-4cc0-ab72-f76d8389182a  (30.186342, -97.925433)
# 4  RouteID_9ea87ee2-867b-4cc0-ab72-f76d8389182a  (30.186342, -97.925433)
#
#                         to from_id to_id            datetime
# 0  (30.178999, -97.924018)      DS    AR 2018-08-12 13:32:04
# 1  (30.184255, -97.919351)      DS    WR 2018-08-12 13:32:04
# 2  (30.186857, -97.923924)      DS    LQ 2018-08-12 13:32:04
# 3  (30.177748, -97.923552)      DS    PT 2018-08-12 13:32:04
# 4  (30.445236, -97.709418)      DS    PZ 2018-08-12 13:32:04

# %% [markdown]
# #### Apply Travel Time

# %%
tt_json = json.loads(open(os.path.join(data_path, "travel_times.json"), "r").read())

# %%
tt_json["RouteID_5d3893c7-c410-486c-8f51-42f70942c376"]['IV']['CG']
# Out:
# 0.0

# %%
# remove ids that are note in route_location_df
keep_routes = set(tt_df["route_id"].unique())
tt_json = {k: v for k, v in tt_json.items() if k in keep_routes}

# %%
def add_travel_time(row,):
    return tt_json[row[0]][row[2]][row[1]]


tt_df['tt'] = tt_df[['route_id', 'to_id', 'from_id']].apply(add_travel_time, axis=1, raw=True).values
# tt_df[('r2', 'tt')] = tt_df[[('route_2', ''), ('r2', "to_id"), ('r2', "from_id")]].apply(add_travel_time, axis=1, raw=True).values
# tt_df[('r1', 'tt)]] = tt_df[[('route_1', ''), ('r1', "to_id"), ('r1', "from_id")]].apply(add_travel_time, axis=1, raw=True)

# %% [markdown]
# #### Check Whether From/To actually occured

# %%
def check_actual_occurance(row,):
    return (row[1], row[2]) in sequential_pairs[row[0]]

tt_df['actual_occurance'] = tt_df[['route_id', 'from_id', 'to_id']].apply(check_actual_occurance, axis=1, raw=True)

# %% [markdown]
# ### Calculate the Travel Time Estimate Differences for a give Pair

# %%
grouper = tt_df.groupby(['from', 'to'])

# %%
grouped_df = grouper.agg({'tt': ('mean', 'std', 'min', 'max'), 'route_id': 'nunique', 'actual_occurance': 'max'}, )
grouped_df.head()
# Out:
#                                                     tt                       \
#                                                   mean  std     min     max
# from                   to
# (30.129676, -97.96375) (30.136697, -97.960858)   181.4  0.0   181.4   181.4
#                        (30.137279, -97.961708)   195.5  0.0   195.5   195.5
#                        (30.137574, -97.957124)   203.5  0.0   203.5   203.5
#                        (30.152141, -97.95341)   1004.7  0.0  1004.7  1004.7
#                        (30.156254, -97.948389)   881.0  0.0   881.0   881.0
#
#                                                route_id actual_occurance
#                                                 nunique              max
# from                   to
# (30.129676, -97.96375) (30.136697, -97.960858)        2            False
#                        (30.137279, -97.961708)        2            False
#                        (30.137574, -97.957124)        2             True
#                        (30.152141, -97.95341)         2            False
#                        (30.156254, -97.948389)        2            False

# %%
grouped_df['tt_diff'] = grouped_df[('tt', 'max')] - grouped_df[('tt', 'min')]

# %% [markdown]
# #### Percent of Locations that Have TT Estimate Deviation

# %%
(len(grouped_df.loc[grouped_df[('tt', 'std')] > 0]) / len(grouped_df)) * 100
# Out:
# 9.869566177967766

# %% [markdown]
# #### Percent of Location Pairs that Actually Occur

# %%
sum(grouped_df[('actual_occurance', 'max')]),  len(grouped_df), (sum(grouped_df[('actual_occurance', 'max')]) / len(grouped_df)) * 100
# Out:
# (47226, 3349438, 1.4099678811788725)

# %%
slicer = grouped_df[('tt', 'std')] > 0

sum(grouped_df.loc[slicer, ('actual_occurance', 'max')]),  len(grouped_df.loc[slicer]), (sum(grouped_df.loc[slicer, ('actual_occurance', 'max')]) / len(grouped_df.loc[slicer])) * 100
# Out:
# (4901, 330575, 1.4825682522876806)

# %% [markdown]
# #### Looking at Location Pairs that Actually Occur

# %%
grouped_df.loc[grouped_df[('actual_occurance', 'max')]].sort_values(('route_id', 'nunique'), ascending=False)
# Out:
#                                                          tt             \
#                                                        mean        std
# from                     to
# (47.937344, -122.244952) (47.661534, -122.32403)   2150.025  10.522896
# (47.464945, -122.231073) (47.517331, -122.367252)  1500.700   0.000000
# (33.965477, -117.653303) (33.834075, -117.90135)   2320.200   0.000000
# (47.937344, -122.244952) (47.661825, -122.294561)  2519.100   0.000000
# (33.965477, -117.653303) (33.891214, -117.509918)  1623.700   0.000000
# ...                                                     ...        ...
# (34.023073, -117.87946)  (34.023937, -117.879214)    14.500   0.000000
# (34.023079, -118.425881) (34.022273, -118.424621)    76.600   0.000000
#                          (34.022626, -118.424898)    72.800   0.000000
# (34.023101, -117.874969) (34.023668, -117.875301)    14.100   0.000000
# (48.124759, -122.162626) (48.124106, -122.161774)    69.400   0.000000
#
#                                                                   route_id  \
#                                                       min     max  nunique
# from                     to
# (47.937344, -122.244952) (47.661534, -122.32403)   2145.6  2184.6       16
# (47.464945, -122.231073) (47.517331, -122.367252)  1500.7  1500.7       11
# (33.965477, -117.653303) (33.834075, -117.90135)   2320.2  2320.2       10
# (47.937344, -122.244952) (47.661825, -122.294561)  2519.1  2519.1       10
# (33.965477, -117.653303) (33.891214, -117.509918)  1623.7  1623.7        9
# ...                                                   ...     ...      ...
# (34.023073, -117.87946)  (34.023937, -117.879214)    14.5    14.5        2
# (34.023079, -118.425881) (34.022273, -118.424621)    76.6    76.6        2
#                          (34.022626, -118.424898)    72.8    72.8        2
# (34.023101, -117.874969) (34.023668, -117.875301)    14.1    14.1        2
# (48.124759, -122.162626) (48.124106, -122.161774)    69.4    69.4        2
#
#                                                   actual_occurance tt_diff
#                                                                max
# from                     to
# (47.937344, -122.244952) (47.661534, -122.32403)              True    39.0
# (47.464945, -122.231073) (47.517331, -122.367252)             True     0.0
# (33.965477, -117.653303) (33.834075, -117.90135)              True     0.0
# (47.937344, -122.244952) (47.661825, -122.294561)             True     0.0
# (33.965477, -117.653303) (33.891214, -117.509918)             True     0.0
# ...                                                            ...     ...
# (34.023073, -117.87946)  (34.023937, -117.879214)             True     0.0
# (34.023079, -118.425881) (34.022273, -118.424621)             True     0.0
#                          (34.022626, -118.424898)             True     0.0
# (34.023101, -117.874969) (34.023668, -117.875301)             True     0.0
# (48.124759, -122.162626) (48.124106, -122.161774)             True     0.0
#
# [47226 rows x 7 columns]

# %%
def sort_tt_df_by_location_pair(pair_1, pair_2):
    return tt_df.loc[(tt_df['from'] == pair_1) & (tt_df['to'] == pair_2)]

# %%
sort_tt_df_by_location_pair((47.937344, -122.244952),	(47.661534, -122.32403)).sort_values('datetime')
# Out:
#                                              route_id  \
# 6267591  RouteID_eb266843-1320-45e3-94fc-784a027a6bf8
# 6303380  RouteID_e6687a05-2453-4edc-b86c-7558ab6d93f6
# 6269221  RouteID_bcb1dd8c-6e7a-4f1c-8546-933131335d69
# 6266606  RouteID_d73e07a2-4a0a-4457-aea5-96114e36e318
# 6251160  RouteID_b9825940-2bbf-4356-8d61-1d1339c9070c
# 6249677  RouteID_40df29e4-d5a3-4f3c-adc0-04465a890696
# 6276529  RouteID_349fe1a3-b174-415c-bf90-d3218c0afc30
# 6263172  RouteID_4ee6e0c9-a4e9-4e61-8d09-e271daeaa28f
# 6261162  RouteID_2fbce317-4620-4360-8e71-3a69e00d3823
# 6272239  RouteID_06751fe1-263c-441a-b482-f7c5d8295c39
# 6274711  RouteID_f18e9349-b11e-4515-ac9b-b6cda718c33c
# 6264761  RouteID_c79a2e9e-56f9-470d-bacf-ed38e0bfaea1
# 6284149  RouteID_917b4ad6-10d4-4349-b8df-8e0fe4339d0b
# 6270164  RouteID_f0c0ce14-6d62-4861-8850-82dbe51f178e
# 6273547  RouteID_0ea8ffd3-673d-473e-8219-382f2a88c999
# 6298160  RouteID_6fd45936-8921-49bd-b9c3-e690bbd1b11d
#
#                              from                       to from_id to_id  \
# 6267591  (47.937344, -122.244952)  (47.661534, -122.32403)      RE    GQ
# 6303380  (47.937344, -122.244952)  (47.661534, -122.32403)      GM    DR
# 6269221  (47.937344, -122.244952)  (47.661534, -122.32403)      BO    JD
# 6266606  (47.937344, -122.244952)  (47.661534, -122.32403)      EA    MQ
# 6251160  (47.937344, -122.244952)  (47.661534, -122.32403)      WQ    YX
# 6249677  (47.937344, -122.244952)  (47.661534, -122.32403)      DY    QU
# 6276529  (47.937344, -122.244952)  (47.661534, -122.32403)      RG    DS
# 6263172  (47.937344, -122.244952)  (47.661534, -122.32403)      VF    PI
# 6261162  (47.937344, -122.244952)  (47.661534, -122.32403)      TS    UM
# 6272239  (47.937344, -122.244952)  (47.661534, -122.32403)      AU    LX
# 6274711  (47.937344, -122.244952)  (47.661534, -122.32403)      SX    ZH
# 6264761  (47.937344, -122.244952)  (47.661534, -122.32403)      NF    AO
# 6284149  (47.937344, -122.244952)  (47.661534, -122.32403)      VL    GA
# 6270164  (47.937344, -122.244952)  (47.661534, -122.32403)      XJ    KX
# 6273547  (47.937344, -122.244952)  (47.661534, -122.32403)      ZW    XZ
# 6298160  (47.937344, -122.244952)  (47.661534, -122.32403)      KY    TS
#
#                    datetime      tt  actual_occurance
# 6267591 2018-07-20 15:30:57  2145.6             False
# 6303380 2018-07-25 15:10:55  2145.6             False
# 6269221 2018-07-26 14:51:20  2147.5             False
# 6266606 2018-07-27 15:46:45  2145.6             False
# 6251160 2018-07-29 15:53:52  2145.6             False
# 6249677 2018-07-31 16:00:00  2145.6              True
# 6276529 2018-08-04 14:48:57  2145.6             False
# 6263172 2018-08-09 15:17:52  2145.6             False
# 6261162 2018-08-11 16:00:00  2161.7             False
# 6272239 2018-08-13 15:49:43  2145.6             False
# 6274711 2018-08-16 15:01:20  2145.6             False
# 6264761 2018-08-17 15:07:37  2145.6             False
# 6284149 2018-08-18 14:59:58  2145.6             False
# 6270164 2018-08-21 14:52:04  2159.4             False
# 6273547 2018-08-23 15:09:28  2145.6             False
# 6298160 2018-08-26 15:44:54  2184.6             False

# %% [markdown]
# ### Show the Location Pairs with Highest Amount of Difference

# %%
grouped_df.loc[grouped_df[('tt', 'std')] > 0, ].sort_values(('tt_diff'), ascending=False).head()
# Out:
#                                                   tt                     \
#                                                 mean         std    min
# from                    to
# (42.184325, -71.288743) (42.16578, -71.36275)  559.4  541.078109  176.8
# (42.166706, -71.36514)  (42.16578, -71.36275)  432.7  484.085302   90.4
# (42.173143, -71.60861)  (42.1247, -71.610638)  441.5  472.913015  107.1
# (42.173863, -71.610895) (42.1247, -71.610638)  438.0  472.913015  103.6
# (42.165268, -71.363573) (42.16578, -71.36275)  409.1  471.923066   75.4
#
#                                                      route_id  \
#                                                  max  nunique
# from                    to
# (42.184325, -71.288743) (42.16578, -71.36275)  942.0        2
# (42.166706, -71.36514)  (42.16578, -71.36275)  775.0        2
# (42.173143, -71.60861)  (42.1247, -71.610638)  775.9        2
# (42.173863, -71.610895) (42.1247, -71.610638)  772.4        2
# (42.165268, -71.363573) (42.16578, -71.36275)  742.8        2
#
#                                               actual_occurance tt_diff
#                                                            max
# from                    to
# (42.184325, -71.288743) (42.16578, -71.36275)            False   765.2
# (42.166706, -71.36514)  (42.16578, -71.36275)            False   684.6
# (42.173143, -71.60861)  (42.1247, -71.610638)            False   668.8
# (42.173863, -71.610895) (42.1247, -71.610638)            False   668.8
# (42.165268, -71.363573) (42.16578, -71.36275)            False   667.4

# %% [markdown]
# ### Plotting the Data

# %%
import openrouteservice as ors

ors_client = ors.Client(key=os.environ["ORS_KEY"])


def get_ors_travel_time(locations, destination_indexes):
    return ors_client.distance_matrix(
        locations,
        destinations=destination_indexes,
        profile="driving-hgv",
        metrics=["duration", "distance"],
    )

# %%
# _r[("to", "")][::-1], _r[("from", "")][::-1]
# https://www.google.com/maps/dir/30.185226,+-97.948886/30.161271,+-97.9378/@30.1844003,-97.954117,3824m/data=!3m1!1e3!4m14!4m13!1m5!1m1!1s0x0:0x58774e0e18241f40!2m2!1d-97.948886!2d30.185226!1m5!1m1!1s0x0:0xc8a5fe56814b73e4!2m2!1d-97.9378!2d30.161271!3e0

# %%
# def make_fig(trace):

#     fig = go.Figure()

#     fig.update_layout(
#         # autosize=True,
#         # showlegend=False,
#         height=600,
#         width=1000,
#         hovermode="closest",
#         mapbox=go.layout.Mapbox(
#             accesstoken=os.environ["MAPBOX_KEY"],
#             # style="mapbox://styles/max-schrader/ck8t1cmmc02wk1it9rv28iyte",
#             style="mapbox://styles/max-schrader/cl6lhvrfw001516pkh3s6iv7l",
#             bearing=0,
#             center=go.layout.mapbox.Center(
#                 lat=route_df["lat"].mean(), lon=route_df["lng"].mean()
#             ),
#             pitch=0,
#             zoom=5,
#         ),
#         # margin=go.layout.Margin(l=0, r=0, t=0, b=0),
#     )

#     fig.add_trace(
#         trace
#     )

#     return fig


# for j in range(5):
#     i = 0
#     _r = tt_df.sort_values(('tt_diff', ''), ascending=False).iloc[j]
#     for r_id, r_stops in [[_r.route_1.values[0], (_r[('r1', 'to_id')], _r[('r1', 'from_id')])], [_r.route_2.values[0], (_r[('r2', 'to_id')], _r[('r2', 'from_id')])]]:
#         _df = route_df.loc[(route_df.route_id == r_id) & (route_df.stop_id.isin(r_stops))]
#         if i == 0:
#             res = get_ors_travel_time([_r[("to", "")][::-1], _r[("from", "")][::-1]], [1])
#             print("ORS Estimated TT", res['durations'][0])
#             print("ORS Estimated Distance", res['distances'][0])
#             i += 1
#             fig = make_fig(
#             go.Scattermapbox(
#                 name=r_id,
#                 lat=_df["lat"],
#                 lon=_df["lng"],
#                 mode="markers+text",
#                 marker=dict(
#                     size=10,
#                 ),
#                 text=r_stops,
#                 textfont=dict(
#                     family="sans serif",
#                     size=22,
#                     # weight=5,
#                     color="white"
#                 ),
#             )
#             )
#         print(r_id, _df.departure_datetime.unique()[0], tt_json[r_id][r_stops[0]][r_stops[1]], tt_json[r_id][r_stops[1]][r_stops[0]])
#     fig.show()

#     print("----------------------------------------------------\n\n")

# %%
get_ors_travel_time([(47.517331, -122.367252)[::-1], (47.464945, -122.231073)[::-1]], [1])
# Out:
# {'durations': [[1479.18], [0.0]],
#  'distances': [[16799.52], [0.0]],
#  'destinations': [{'location': [-122.23167, 47.464705],
#    'snapped_distance': 52.22}],
#  'sources': [{'location': [-122.367296, 47.517332], 'snapped_distance': 3.29},
#   {'location': [-122.23167, 47.464705], 'snapped_distance': 52.22}],
#  'metadata': {'attribution': 'openrouteservice.org | OpenStreetMap contributors',
#   'service': 'matrix',
#   'timestamp': 1660738850751,
#   'query': {'locations': [[-122.367252, 47.517331], [-122.231073, 47.464945]],
#    'profile': 'driving-hgv',
#    'responseType': 'json',
#    'metricsStrings': ['DISTANCE', 'DURATION'],
#    'destinations': ['1'],
#    'metrics': ['duration', 'distance']},
#   'engine': {'version': '6.7.0',
#    'build_date': '2022-02-18T19:37:41Z',
#    'graph_date': '2022-08-01T21:12:42Z'}}}
